# %% [markdown]
# # Результат ревью:
#
# Екатерина, был единственный красный комментарий в твоей работе, но сейчас его нет. Соответственно нет и никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня прямо сейчас.
#
# ПРОЕКТ ПРИНЯТ!
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s Повторюсь, что для дальнейшего совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/.
#
# p.p.s Я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Привет Екатерина!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 54

# %%
data = data.drop_duplicates()

# %% [markdown]
# **Задание 15. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ## Исследуйте данные и ответьте на вопросы

# %% [markdown]
# **Задание 19. Есть ли зависимость между количеством детей и возвратом кредита в срок?**

# %% [markdown]
# <div class="alert-info">
#
# **В заданиях 19 - 22 навела "марафет":**
# - комментарии к кодам теперь расположены в сроках типа Markdown  перед кодом
# - длинные строки прописаны с переносом на новую строку, чтобы тебе не приходилось скроллить при проверке.
#     </div>

# %% [markdown]
# Создадим сводную таблицу, показывающую количество клиентов с задолженностью и без задолженности для каждой категории клиентов(клиенты поделены на категории в зависимости от количества детей)

# %%
data_children_pivot = data.pivot_table(index='children', columns='debt', values='income_type', aggfunc='count')
data_children_pivot
# Out:
# debt            0       1
# children
# 0         13044.0  1063.0
# 1          4365.0   444.0
# 2          1858.0   194.0
# 3           303.0    27.0
# 4            37.0     4.0
# 5             9.0     NaN

# %% [markdown]
# Создадим столбец, показывающий для каждой категории заёмщиков долю клиентов, заплативших кредит в срок, от общего числа клиентов.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке, что "режет" глаз и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Сейчас, у тебя они расположены справа, поэтому мне, чтобы увидеть, что там написано приходится пользоваться скроллиногом. Добивайся того, чтобы ячейку не приходилось прокручивать. Это не добавляет удобства ни тебе, при отладке кода, ни мне, для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает.
#
# Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
#
# p.s. я смотрю код ниже и вижу, что нужно и ячейки ниже приводить к рекомендуемому стилю. Пожалуйста сделай это.
# </div>

# %%
data_children_pivot['rate_of_payed_in_time_people'] = data_children_pivot[0]/(data_children_pivot[0]+data_children_pivot[1])
data_children_pivot
# Out:
# debt            0       1  rate_of_payed_in_time_people
# children
# 0         13044.0  1063.0                      0.924647
# 1          4365.0   444.0                      0.907673
# 2          1858.0   194.0                      0.905458
# 3           303.0    27.0                      0.918182
# 4            37.0     4.0                      0.902439
# 5             9.0     NaN                           NaN

# %% [markdown]
# Убираем мультииндекс.

# %%
data_children_pivot_reset_index = data_children_pivot.reset_index()
data_children_pivot_reset_index
# Out:
# debt  children        0       1  rate_of_payed_in_time_people
# 0            0  13044.0  1063.0                      0.924647
# 1            1   4365.0   444.0                      0.907673
# 2            2   1858.0   194.0                      0.905458
# 3            3    303.0    27.0                      0.918182
# 4            4     37.0     4.0                      0.902439
# 5            5      9.0     NaN                           NaN

# %% [markdown]
# Для наглядности сортируем датасет по доле клиентов, заплативших кредит в срок.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Этого можно было не делать. И по предыдущей сводной таблице уже вывод можно делать.
# </div>

# %%
data_children_pivot_reset_index.sort_values(by='rate_of_payed_in_time_people', ascending=False)
# Out:
# debt  children        0       1  rate_of_payed_in_time_people
# 0            0  13044.0  1063.0                      0.924647
# 3            3    303.0    27.0                      0.918182
# 1            1   4365.0   444.0                      0.907673
# 2            2   1858.0   194.0                      0.905458
# 4            4     37.0     4.0                      0.902439
# 5            5      9.0     NaN                           NaN

# %% [markdown]
# **Вывод:**

# %% [markdown]
# Разделив заёмщиков на категории по количеству детей, приходим к выводу, что чаще всего кредит в срок закрывают клиенты, не имеющие детей.
# Это обусловлено тем, что у данной категории клиентов, как правило,  меньше ежемесячных обязательных трат.
# Затем идут многодетные клиенты с 3-мя детьми, а затем с одним ребёнком.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, конечно «разбег» между цифрами мал. Возможно, что в рамках имеющихся данных сделать вывод о том, что семьи с детьми относительно семей без оных имеют какие-то задержки в выплатах кредитов нельзя. Слишком уж близки доли, чуть измениться выборка и значения могут измениться в другую сторону. То есть можно сделать вывод, что сколь угодно значимой разницы между группами нет.
#
# Но если считать, что **любая** разница между группами есть повод для «разделения» классов, то я бы сделал такой вывод: кредитополучатели без детей являются более ответственными, чем клиенты, у которых есть дети. Видимо, наличие ребенка накладывает на клиента дополнительные финансовое бремя (обязательства) и клиенты либо менее ответственно относятся к своим кредитным обязательствам, либо не имеют возможности в срок оплачивать обязательства.
#
# Верно «пойман» и тот момент, что по некоторым группам заемщиков у нас недостаточно данных. Говорят, что выборка несбалансирована, классы в выборке имеют разные размеры.
#
# **Затем идут многодетные клиенты с 3-мя детьми** - возможно, что для них рождение ребенка — это некий шок, влияющий на исполнение финансовых обязательств. В то время как для семей с большим количеством детей - дети стали обыденностью))) </div>

# %% [markdown]
# **Задание 20. Есть ли зависимость между семейным положением и возвратом кредита в срок?**

# %% [markdown]
# Создадим сводную таблицу, показывающую количество клиентов с задолженностью и без задолженности для каждой категории клиентов(клиенты поделены на категории в зависимости от семейного положения)

# %%
data_family_status_pivot = data.pivot_table(index='family_status', columns='debt', values='income_type', aggfunc='count')
data_family_status_pivot
# Out:
# debt                       0    1
# family_status
# Не женат / не замужем   2523  273
# в разводе               1105   84
# вдовец / вдова           888   63
# гражданский брак        3761  385
# женат / замужем        11339  927

# %% [markdown]
# Создадим столбец, показывающий для каждой категории клиентов долю клиентов, заплативших кредит в срок, от общего числа клиентов.

# %%
data_family_status_pivot['rate_of_payed_in_time_people'] = \
data_family_status_pivot[0]/(data_family_status_pivot[0]+data_family_status_pivot[1])
data_family_status_pivot
# Out:
# debt                       0    1  rate_of_payed_in_time_people
# family_status
# Не женат / не замужем   2523  273                      0.902361
# в разводе               1105   84                      0.929352
# вдовец / вдова           888   63                      0.933754
# гражданский брак        3761  385                      0.907139
# женат / замужем        11339  927                      0.924425

# %% [markdown]
# Убираем мультииндекс

# %%
data_family_status_pivot_reset_index = data_family_status_pivot.reset_index()
data_family_status_pivot_reset_index
# Out:
# debt          family_status      0    1  rate_of_payed_in_time_people
# 0     Не женат / не замужем   2523  273                      0.902361
# 1                 в разводе   1105   84                      0.929352
# 2            вдовец / вдова    888   63                      0.933754
# 3          гражданский брак   3761  385                      0.907139
# 4           женат / замужем  11339  927                      0.924425

# %% [markdown]
# Для наглядности сортируем датасет по доле клиентов, заплативших кредит в срок

# %%
data_family_status_pivot_reset_index.sort_values(by='rate_of_payed_in_time_people', ascending=False)
# Out:
# debt          family_status      0    1  rate_of_payed_in_time_people
# 2            вдовец / вдова    888   63                      0.933754
# 1                 в разводе   1105   84                      0.929352
# 4           женат / замужем  11339  927                      0.924425
# 3          гражданский брак   3761  385                      0.907139
# 0     Не женат / не замужем   2523  273                      0.902361

# %% [markdown]
# Вывод:Разделив заёмщиков на категории по семейному статусу, приходим к выводу, что чаще всего кредит в срок закрывают овдовевшие клиенты.Возможно это обусловлено тем, что цель, под которую брался кредит, более не актуальна. Затем идут разведённые клиенты, а затем клиенты,состоящие в официальном браке.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь верно. Кредитному отделу следует с осторожностью относиться к клиентам, которые не состоят или не состояли в браке. Согласно данным такие клиенты менее ответственные. Получается, что узаконенные отношения ведут к более ответственному отношению к своим обязательствам. Ну вроде как совпадает со здравым смыслом - семейные люди более скрупулёзно берегут свой семейное спокойствие и несут за него ответственность.
#
# Верно «пойман» и тот момент, что по некоторым группам заемщиков у нас недостаточно данных. Говорят, что выборка несбалансирована, классы в выборке имеют разные размеры.</div>

# %% [markdown]
# **Задание 21. Есть ли зависимость между уровнем дохода и возвратом кредита в срок?**

# %% [markdown]
# Создадим сводную таблицу, показывающую количество клиентов с задолженностью и без задолженности для каждой категории клиентов(клиенты поделены на категории в зависимости от категории дохода)

# %%
data_total_income_category_pivot = data.pivot_table \
(index='total_income_category', columns='debt', values='income_type', aggfunc='count')
data_total_income_category_pivot
# Out:
# debt                       0     1
# total_income_category
# A                         23     2
# B                       4660   354
# C                      14585  1353
# D                        328    21
# E                         20     2

# %% [markdown]
# Создадим столбец, показывающий для каждой категории клиентов долю клиентов, заплативших кредит в срок, от общего числа клиентов.

# %%
data_total_income_category_pivot['rate_of_payed_in_time_people'] = \
data_total_income_category_pivot[0]/(data_total_income_category_pivot[0]+data_total_income_category_pivot[1])
data_total_income_category_pivot
# Out:
# debt                       0     1  rate_of_payed_in_time_people
# total_income_category
# A                         23     2                      0.920000
# B                       4660   354                      0.929398
# C                      14585  1353                      0.915109
# D                        328    21                      0.939828
# E                         20     2                      0.909091

# %% [markdown]
# Убираем мультииндекс

# %%
data_total_income_category_pivot_reset_index = data_total_income_category_pivot.reset_index()
data_total_income_category_pivot_reset_index
# Out:
# debt total_income_category      0     1  rate_of_payed_in_time_people
# 0                        A     23     2                      0.920000
# 1                        B   4660   354                      0.929398
# 2                        C  14585  1353                      0.915109
# 3                        D    328    21                      0.939828
# 4                        E     20     2                      0.909091

# %% [markdown]
# Для наглядности сортируем датасет по доле клиентов, заплативших кредит в срок

# %%
data_total_income_category_pivot_reset_index.sort_values(by='rate_of_payed_in_time_people', ascending=False)
# Out:
# debt total_income_category      0     1  rate_of_payed_in_time_people
# 3                        D    328    21                      0.939828
# 1                        B   4660   354                      0.929398
# 0                        A     23     2                      0.920000
# 2                        C  14585  1353                      0.915109
# 4                        E     20     2                      0.909091

# %% [markdown]
# **Вывод:**

# %% [markdown]
# В задании 16 датасет был дополнен столбцом с категориями доходов, созданных на основании значений ежемесячного дохода заёмщиков:
# 0–30000 — 'E';
# 30001–50000 — 'D';
# 50001–200000 — 'C';
# 200001–1000000 — 'B';
# 1000001 и выше — 'A'.
# Разделив заёмщиков на категории по вышеуказанным категориям доходов, приходим к выводу, что чаще всего кредит в срок закрывают клиенты, с категорией доходов "D" и, соответстсвенно, с ежемесячным доходом от 30001 до 50000.
# Согласно данным росстата, ежемесячный доход заёмщиков этой категории близок к среднему доходу людей в провинциальных регионах РФ (за исключением северных регионов).
# Таким образом, представители регионов, обладающие средним уровнем заработка в рамках своего региона, являюся одними из самых добросовестных клиентов в части своевременного закрытия кредитов.
# Затем идут клиенты с категорией дохода "B"(доход от 200001 до 1000000), а затем с "A"(доход от 1000001 и выше).
# Реже всего, что логично, кредит в срок закрывают клиенты с наименьшим уровнем дохода - категория "E".

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Исходя из здравого смысла логично предположить, что чаще всего должниками становятся люди с небольшим доходом, которым финансовые проблемы не позволяют вовремя осуществлять платежи. Но глядя на наши результаты лично мой вывод таков: выборка по заемщикам, как с наименьшим доходом, так и с наибольшим крайне недостаточна для формирования однозначных выводов. Можно думать, что E-категория самая низкооплачиваемая не может корректно распоряжаться деньгами и «влезает» в кредиты, но тогда неясно почему у А-категории также достаточно высокий процент задолженности. В общем вывод по группам А и Е неочевиден, мало данных.
#
# Если же взять для анализа только группы В, С и D, то по полученным данным не наблюдаем зависимости "те кто получает больше ЗП, лучше возвращает кредит». В целом это логично, так как материальный достаток - не единственная переменная которая влияет на качество кредитной истории.</div>

# %% [markdown]
# **Задание 22. Как разные цели кредита влияют на его возврат в срок?**

# %% [markdown]
# Создадим сводную таблицу, показывающую количество клиентов с задолженностью и без задолженности для каждой категории клиентов(клиенты поделены на категории в зависимости от категории цели кредита)

# %%
data_purpose_category_pivot = data.pivot_table(index='purpose_category', columns='debt', values='income_type', aggfunc='count')
data_purpose_category_pivot
# Out:
# debt                         0    1
# purpose_category
# операции с автомобилем    3881  400
# операции с недвижимостью  9974  780
# получение образования     3620  369
# проведение свадьбы        2141  183

# %% [markdown]
# Создадим столбец, показывающий для каждой категории клиентов долю клиентов, заплативших кредит в срок, от общего числа клиентов.

# %%
data_purpose_category_pivot['rate_of_payed_in_time_people'] = \
data_purpose_category_pivot[0]/(data_purpose_category_pivot[0]+data_purpose_category_pivot[1])
data_purpose_category_pivot
# Out:
# debt                         0    1  rate_of_payed_in_time_people
# purpose_category
# операции с автомобилем    3881  400                      0.906564
# операции с недвижимостью  9974  780                      0.927469
# получение образования     3620  369                      0.907496
# проведение свадьбы        2141  183                      0.921256

# %% [markdown]
# Убираем мультииндекс

# %%
data_purpose_category_pivot_reset_index = data_purpose_category_pivot.reset_index()
data_purpose_category_pivot_reset_index
# Out:
# debt          purpose_category     0    1  rate_of_payed_in_time_people
# 0       операции с автомобилем  3881  400                      0.906564
# 1     операции с недвижимостью  9974  780                      0.927469
# 2        получение образования  3620  369                      0.907496
# 3           проведение свадьбы  2141  183                      0.921256

# %% [markdown]
# Для наглядности сортируем датасет по доле клиентов, заплативших кредит в срок

# %%
data_purpose_category_pivot_reset_index.sort_values(by='rate_of_payed_in_time_people', ascending=False)
# Out:
# debt          purpose_category     0    1  rate_of_payed_in_time_people
# 1     операции с недвижимостью  9974  780                      0.927469
# 3           проведение свадьбы  2141  183                      0.921256
# 2        получение образования  3620  369                      0.907496
# 0       операции с автомобилем  3881  400                      0.906564

# %% [markdown]
# Вывод:Чаще всего в срок возвращают кредиты, взятые на покупку недвижимости. Для многих заёмщиков данный объект недвижимости является единственным местом жительства, находясь при этом в залоге у банка до момента погашения кредита. Поэтому неудивительно, что люди наиболее ответственно относятся к погашению именно этой категории кредитов.
# Затем идут кредиты, взятые на проведение свадьбы, и на получение образования.
# По автокредитам наблюдается наименьшее количество заёмщиков, своевременного выполняющих обязательства по платежам.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Всё подтверждается и цифрами, и здравым смыслом. Машины люди покупают в кредит гораздо дорогие, нежели могут соответствовать им своим доходом (ну кому не хочется красивую иномарку). А вот рисковать ипотечным жильём люди не хотят. Интересно конечно что с образованием не так - как правило такие кредиты берут люди мотивированные, имеющие цель впереди, да и суммы таких кредитов судя по рынку онлайн образования не так велики.</div>

# %% [markdown]
# **Задание 23. Приведите возможные причины появления пропусков в исходных данных.**

# %% [markdown]
# Пропуски в столбце 'total_income' могли поставить безработные граждане.
# Пропуски в столбце 'days_employed' могли поставить студенты.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, всё здраво. Эти возможные причины сразу и приходят в голову.</div>

# %% [markdown]
# **Задание 24. Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.**

# %% [markdown]
# Применеие медианы актуально в ситуациях, когда в вариационном ряду есть отдельные члены, которые намного больше или меньше остальных, а объём совокупности невелик.
# При работе с количественными переменными среднее значение использовать некорректно, так как оно является слишком чувствительным параметром к так называемым «выбросам» — нехарактерным для изучаемой выборки,слишком большим или слишком малым значением.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, в случае, если в данных наблюдаются "выбросы", то даже небольшое их количество может сильно "перетягивать" среднее значение в большую или меньшую сторону. Медиана зачастую даёт более правдивую картину. В общем случае, в реальных "живых" проектах я рекомендую в каждом случае смотреть на то, как распределены данные.
# </div>

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# Изучив статистику о платёжеспособности клиентов, приходим к выводу, что на факт погашения кредита в срок влиет множество факторов:семейное положение клиента, количество детей, уровень дохода и цель кредита.
# Сделанный анализ с влиянием каждого фактора на платёжеспособность клиента сможет использовать кредитный отдел банка
# при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий 👉</b>
#
# Финальный вывод конечно нужно более детальным сделать. Общий вывод - это изюминка твоей работы. Большинство заказчиков посмотрят сначала его (а некоторые только его). Чтобы выводы не огорошивали заказчика своей очевидностью, стоит добавить в них цифр, выводов, коэффициентов корреляций, графиков. Сделай так, чтобы вся найденная в данных информация была отражена в выводе.
#
# Твои, как аналитика, выводы - это данные ("алмаз"), которые родились из большого объёма неструктурированной, зачастую, казалось бы, несвязанной между собой информации ("горной породы").
#
# Для "не специалиста", поверь, выводы, которые ты делаешь будут казаться чем-то сродни волшебства. Эти люди "не специалисты" не будут понимать, НУ КАК ВОТ из наших табличек с кредитами можно было достать выводы, для того, чтобы спрогнозировать возврат/невозврат кредита.
#
# Но то, что они не понимают всего процесса - это не их беда. Просто они работают по-другому и мыслят другими категориями. Под "этими людьми" я здесь имею в виду топ-менеджеров, генеральных директоров и может быть ещё более высокий уровень. Их уровень понимания - это красивая и понятная им презентация в PowerPoint, с графиками бизнес показателей, с цифрами. Презентация из 3-5-10 слайдов это твоя, как аналитика "лебединая песня", те "алмазы", которые получены и облечены в ту форму, которая позволит лицам, принимающим решения принять такие зачастую многомилионной стоимости решения, которые напрямую повлияют на тот бизнес в котором ты работаешь.
# Возможный пример вывода - в виде скрина:
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# <div class="alert-info">
#
# **О сроках проверки.**
#
# Александр, большое спасибо тебе за оперативную проверку первой итерации моего проекта! \
# Если возможно, прошу мою вторую попытку проверить столь же молниеносно;) \
# Горю по срокам, а попасть на академ не очень-то хочется..
# </div>

# %% [markdown]
# <div class="alert-info">
#
# **Новый общий вывод.**
#
# Проведено исследование с целью выявления влияния разных факторов на своевременное погашение заёмщиком кредита.
# Результаты исследования будут учтены при построении модели кредитного скоринга - специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# В ходе исследования проверены 4 гипотезы:
# - Гипотеза 1. Количество детей влияет на  факт погашения кредита в срок.
# - Гипотеза 2. Семейное положение влияет на факт погашения кредита в срок.
# - Гипотеза 3. Уровень дохода влияет на факт погашения кредита в срок.
# - Гипотеза 4. Цель кредита влияет на факт погашения кредита в срок.
#
# В результате исследования удалось выявить следующие зависимости.
#
# **Гипотеза 1 подтверждена:** * чтобы выводы были точнее, нужно больше информации по группам заемщиков с 3, 4 и 5 детьми. Сейчас выборка несбалансирована.
#
# - 92,4% - доля своевременно выплативших кредит заёмщиков без детей.
# - 90,7% - доля своевременно выплативших кредит заёмщиков с 1 ребёнком.
# - 90,5% - доля своевременно выплативших кредит заёмщиков с 2 детьми.
#
# Рекомендация: на основании выявленной завиимости можно оценивать способность потенциального заёмщика вернуть кредит банку. Также  можно провести дополнительное исследование на большей выборке данных, увеличив количество заёмщиков с 3, 4 и 5 детьми.
#
# **Гипотеза 2 подтверждена:**  * чтобы выводы были точнее, нужно больше информации по овдовевшим и разведённым клиентам. Сейчас выборка несбалансирована.
#
# - У людей, официально оформляющих свои отношения, доля своевременно выплачивающих кредит заёмщиков больше:   овдовевшие клиенты - 93,3%, разведённые - 92,9%, состоящие в официальном браке - 92,4%,
# - У заёмщиков, не оформляющих официально свои отношения, доля своевременно выплачивающих кредит меньше: 90,7% - у людей, состоящих в гражданском браке, 90,2% -  у не женатых/не замужних клиентов.
#
#
# Рекомендация: на основании выявленной завиимости можно оценивать способность потенциального заёмщика вернуть кредит банку. Также можно провести дополнительное исследование на большей выборке данных, увеличив в исследовании количество разведённых и овдовевших заёмщиков.
#
# **Гипотеза 3 подтверждена частично:** * чтобы выводы были точнее, нужно больше информации по группам заемщиков с уровнем доходов категории D (от 30 001 до 50 000), категории A (от 1 000 001), категории E (до 30 000). Сейчас выборка несбалансирована.
#
# - 92,9% - доля своевременно выплативших кредит заёмщиков с доходом категории B. (от 200 001 до 1 000 000)
# - 91,5% - доля своевременно выплативших кредит заёмщиков с доходом категории C. (от 50 001 до 200 000)
#
#
# Рекомендация: на основании выявленной завиимости можно оценивать способность потенциального заёмщика вернуть кредит банку. Также  можно провести дополнительное исследование на большей выборке данных, увеличив количество заёмщиков с уровнем доходов категории D (от 30 001 до 50 000), категории A (от 1 000 001), категории E (до 30 000).
#
# **Гипотеза 4 подтверждена:**
#
# - 92,7% - доля своевременно выплативших кредит заёмщиков по кредитам, взятым на операции с недвижимостю .
# - 92,1% - доля своевременно выплативших кредит заёмщиков по кредитам, взятым  на проведение свадьбы.
# - 90,7% - доля своевременно выплативших кредит заёмщиков по кредитам, взятым  на получение образования.
# - 90,6% - доля своевременно выплативших кредит заёмщиков по кредитам, взятым  на операции с автомобилем.
#
# Рекомендация: На основании выявленной завиимости можно оценивать способность потенциального заёмщика вернуть кредит банку.
#
# **Общие рекомендации:**
#
# - Специалистам, занимающимся построением модели кредитного скоринга, можно использовать зависимости, полученные в ходе проверки  гипотез о влиянии на свовевременное погашение кредита количества детей клиента, семейного положения, уровня дохода, цели кредита.
# - Для первой, второй и третьей гипотез  можно провести дополнительное исследование на большей выборке данных.
#
# </div>

# %% [markdown]
# # Результат ревью:
#
# Екатерина, я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Использование механизмов группировки данных (groupby) и создания сводных таблиц (pivot_table) является рекомендуемым и обязательным в данном проекте. Для дальнейшего совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую тебе обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/. Рекомендуемые темы/уроки для освоения тем выше - на скрине ниже.
#
# Есть 1 принципиальный момент, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Финальный вывод в таком виде - это не то, что заказчик ждет от аналитика данных. Ты, как профессионал должна предоставить точные, четки и корректные **прогнозы и рекомендации**, которые помогут твоей компании в реализации скорингового алгоритма. Здесь, в финальном выводе требуется максимально подробно и с цифрами описать все те инсайды в данных, которые были обнаружены в ходе выполнения проекта.</div>
#
# Этот момент требуют твоего внимания. Жду доработанную версию проекта на повторное ревью.
#
# ![image.png](attachment:image.png)
