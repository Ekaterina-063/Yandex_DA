# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут Кузьмич Валентин, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - небольшое исправление графиков
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - [Шкала Чеддока…](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Напиши здесь свои мысли и идеи по поводу комментария ревьюера.
#
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - небольшое исправление графиков
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Я вижу, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - описание данных,
#
# - план работы
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
#
# </div>

# %% [markdown]
# <div class="alert-info">
# Спасибо,буду иметь ввиду.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %%
pd.options.display.float_format = '{:.2f}'.format
real_estate = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %%
real_estate.info()
real_estate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
real_estate.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, построены гистограммы по всем столбцам!
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Задание 2.1** Найдём и изучим пропущенные значения в столбцах.

# %% [markdown]
# **Задание 2.1.1**
# Определим, в каких столбцах есть пропуски.

# %%
real_estate.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Были оценены потери, это очень важно сделать перед тем, как избавляться от данных.
#
# </div>

# %% [markdown]
# **Задание 2.1.2**
# Укажем причины, которые могли привести к пропускам в данных.

# %% [markdown]
# Пропуски есть в столбцах:
# - ceiling_height,
# - floors_total,
# - living_area,
# - is_apartment,
# - kitchen_area,
# - balcony,
# - locality_name,
# - airports_nearest,
# - cityCenters_nearest,
# - parks_around3000,
# - parks_nearest,
# - ponds_around3000,
# - ponds_nearest,
# - days_exposition.
#
# К пропускам в данных, добавленных пользователем, могло привести то, что многие авторы объявлений отавляли пустую ячейку там, где в параметрах объекта недвижимости отсутствует тот или иной критерий. Например, при отсутствии балкона, в графе 'balcony' вместо нуля автор объявления оставял пустую графу; если недвижимость не относится к категории апартаменты (столбец 'is_apartment') - пользователь также мог просто оставить пустую графу.
# Также в этой категории данных пропуски могли возникнуть в ситуациях, когда пользователь торопится подать объявление о продаже, но не имеет под рукой документов на право собственности: т.е. он точно не помнит сколько именно метров состаляет жилая площадь от общей (столбец 'living_area'), сколько метров кухня(столбец'kitchen_area'), точная высота потолков(столбец 'ceiling_height'), количество этажей('floors_total'). Пользователь вероятно рассуждает таким образом: если объявление кого-то заинтересует, то эти данные я уточню позднее по запросу. Или же объявление размещало агенство, где менеджер при размещении объявления, не связался с  хозяином недвижимости и не уточнил все возможные характеристики объекта, запрашиваемые  сайтом при подаче объявления.
#
# Возникновение пропусков в картографическом типе данных предлагаю рассмотреть на примере столбцов: 'parks_around3000' и 'parks_nearest'. Если количество парков (значение в столбце 'parks_around3000') в 3 километрах от объекта недвижимости равно о,  то, соответственно, в столбце 'parks_nearest', где указывается расстояние до ближайшего парка, будет пропущено значение.
#
# Уберём пропущенные значения там, где это возможно и обосновано:

# %% [markdown]
# **Задание 2.1.3**
# Заполним пропущенные значения там, где это возможно:

# %%
real_estate['balcony'] = real_estate['balcony'].fillna(value=0) # пропуски говорят о вероятном отсутствии балкона

# %%
real_estate['ponds_around3000'] = real_estate['ponds_around3000'].fillna(value=0) # пропуски говорят об отсутствии пруда рядом

# %%
real_estate['parks_around3000'] = real_estate['parks_around3000'].fillna(value=0) # пропуски говорит об отсутствии парка рядом

# %%
real_estate['is_apartment'] = real_estate['is_apartment'].fillna(value=False) # пропуски означают, что это не Апартаменты

# %%
real_estate['ceiling_height'] = real_estate['ceiling_height'].fillna(value = 7777) # высоту потолков заполним по среднему значению
ceiling_height_median = real_estate.loc[real_estate['ceiling_height'] != 7777, 'ceiling_height'].median().copy()
real_estate.loc[real_estate['ceiling_height'] == 7777, 'ceiling_height'] = ceiling_height_median

# %% [markdown]
# Количество дней на экспозиции заменю на заглушку 7777, т.к.заменять средним некореектно - возможно эти квартиры ещё на публикации:

# %%
real_estate['days_exposition'] = real_estate['days_exposition'].fillna(value= 7777)

# %%
living_rate = real_estate[real_estate['living_area'].isnull() == False] \
['living_area'].mean()/real_estate['total_area'].mean().copy() # Пропуски заполним по среднему отношению жилой $ к общей $.
real_estate['living_area'] = real_estate['living_area'].fillna(real_estate['total_area'] * living_rate)

# %%
kitchen_rate = real_estate.loc[real_estate['kitchen_area'].isnull() == False,'kitchen_area'] \
.mean()/real_estate['total_area'].mean().copy() # Пропуски заполним по среднему отношению $ кухни к общей $.
real_estate['kitchen_area'] = real_estate['kitchen_area'].fillna(real_estate['total_area'] * kitchen_rate)

# %% [markdown]
# В столбцах с  картографическим типом данных предлагаю вместо пропусков поставить выделяющиеся значения, чтобы можжно было в дальнейшем производить с ними математические операции:

# %%
real_estate['airports_nearest'] = real_estate['airports_nearest'].fillna(value=77777).reset_index(drop=True)
real_estate['cityCenters_nearest'] = real_estate['cityCenters_nearest'].fillna(value=77777).reset_index(drop=True)
real_estate['parks_nearest'] = real_estate['parks_nearest'].fillna(value=77777).reset_index(drop=True)
real_estate['ponds_nearest'] = real_estate['ponds_nearest'].fillna(value=77777).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# В данном случае не правильно заполнять `airports_nearest`, `parks_nearest`, `ponds_nearest` значением-заглушкой. Данные были собраны на основе картографических данных, правильнее `airports_nearest`, `parks_nearest`, `ponds_nearest` оставить пустыми. Далее по проекту их использовать не обязательно, поэтому замечание не критичное.
#
# </div>

# %% [markdown]
# **Задание 2.2**
#
# Найдём столбцы, в которых нужно изменить тип данных.Преобразуем тип данных в выбранных столбцах.
# Поясним, почему нужно изменить тип данных.

# %% [markdown]
# Тип данных по каждому столбцу изначального датасета указан в методе info().
# - Столбец 'first_day_exposition' имеет тип данных object. Исправим это и приведём его к типу данных datetime64, ведь речь идёт о дате и времени.
# - Столбец 'balcony' в изначальном датасете относится к типу данных float64. Количество балконов - явно целое цисло.Можем поменять тип данных на целочисленный int. Также к этому формату можно привести количество дней на экспозиции и цену, ведь с ней предстоит ещё много вычислений.

# %%
real_estate['first_day_exposition'] = pd.to_datetime(real_estate['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
# ...

# %%
real_estate['balcony'] = real_estate['balcony'].astype('int')

# %%
real_estate['days_exposition'] = real_estate['days_exposition'].astype('int')

# %%
real_estate['last_price'] = real_estate['last_price'].round(0).astype(int)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что преобразования типов все в одном месте.
#
# </div>

# %% [markdown]
# **Задание 2.3**
# Изучим уникальные значения в столбце с названиями и устраним неявные дубликаты.

# %%
real_estate['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
real_estate['locality_name']= real_estate['locality_name'].str.replace('ё','е')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что тобою было замечено разное написание слова «посёлок» и было принято решение это исправить 😃
#
# </div>

# %%
real_estate['locality_name']= real_estate['locality_name'].str.replace('городской поселок','поселок городского типа')

# %%
real_estate['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово',
#        'поселок Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %% [markdown]
# **Задание 2.4** Найдём и устраним редкие и выбивающиеся значения: если природа аномалии понятна и данные действительно искажены, то восстановим корректное значение. В противном случае удалим редкие и выбивающиеся значения.

# %% [markdown]
# Считаю необходимым избавиться от объявлений:
#  - где не заполнен адрес, т.к. расположение объекта является важным фактором при ценообразовании, а таких объявлений всего 49 штук
#  - где не указана этажность, т.к.без информации об этажности объекта в дальнейщем мы не сможем правильно создать категории первый/последний этаж. К тому же таких объявлений всего 86.

# %%
real_estate  = real_estate.dropna(axis='index', subset=['locality_name']).reset_index(drop=True)

# %%
real_estate  = real_estate.dropna(axis='index', subset=['floors_total']).reset_index(drop=True)

# %% [markdown]
# Устранение аномальных значений:
# - В столбце ceiling_height считаю аномалиями все объекты с высотой потолков выше 20 метров (даже для элитного жилья - это слишком) и меньше 2 метров.
# - В столбце floors_total являются выбросами все объекты с этажностью  выше 37 этажей, т.к. этажность самого высокого жилого здания в СПБ составляет 37 этажей.

# %%
real_estate.loc[real_estate['ceiling_height'] > 20, 'ceiling_height'] = real_estate['ceiling_height']/10

# %%
real_estate.loc[real_estate['ceiling_height'] < 2,'ceiling_height' ] = ceiling_height_median

# %%
real_estate.loc[real_estate['floors_total'] > 37] # выявлено 2 аномалии, от которых нужно избавиться
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2245             12     3800000       45.50           2018-06-28      2
# 16635             9     3978000       40.00           2018-09-24      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2245             2.88         60.00        27.40      4         False  ...
# 16635            2.65         52.00        10.50     18         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 2245           7.40        0        Кронштадт          67763.00
# 16635         14.00        0  Санкт-Петербург          20728.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 2245             49488.00              2.00         342.00              3.00
# 16635            12978.00              1.00         793.00              0.00
#
#        ponds_nearest  days_exposition
# 2245          614.00              166
# ...

# %%
real_estate.loc[real_estate['floors_total'] == 60, 'floors_total'] = 6 #уберём в объявлении лишний ноль в столбце Этажность

# %% [markdown]
# Думаю также, что аномалиями являются объекты недвижимости стоимостью более 25 млн, количеством комнат свыше 8(),общей площадью больше 200 метров, высотой потолков свыше 4 метров, площадью кухни свыше 35 метров,жилой площадью свыше 120 метров,продающиеся дольше года и свыше 37 этажей(у нас осталось 1 такое объявление).
# Избавимся от таких объявлений:

# %%
real_estate = real_estate.query('rooms <= 8 and last_price < 25000000 and total_area <= 200 and ceiling_height <= 4 \
   and kitchen_area <= 35 and living_area <= 120 and days_exposition <= 365 and floors_total<=37').reset_index(drop=True).copy()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, перед отбросом выбросов очень важно в процентах оценить, сколько мы теряем, должно быть не более 10%.
#
# </div>

# %% [markdown]
# Убедимся, что в датасете не осталось аномальных значений:

# %%
real_estate.loc[(real_estate['ceiling_height'] > 20) | (real_estate['ceiling_height']<2) \
                |(real_estate['floors_total'] > 37) | (real_estate['rooms'] > 8)| (real_estate['last_price'] >= 25000000) \
                | (real_estate['total_area'] > 200) | (real_estate['ceiling_height'] > 4) | (real_estate['kitchen_area'] > 35) \
               |(real_estate['living_area'] > 120) |(real_estate['days_exposition'] > 365)]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Столбец с ценой за метр квадратный:

# %%
real_estate['price_of_square_meter'] = real_estate['last_price']/real_estate['total_area']

# %% [markdown]
# Столбец с днём недели публикации объявления:

# %%
real_estate['weekday'] = real_estate['first_day_exposition'].dt.weekday 
real_estate['weekday'].unique() # публикация осуществляется ежедневно с понедельника(0) по воскресенье (6)
# Out:
# array([1, 0, 3, 2, 6, 5, 4])

# %% [markdown]
# Столбец с месяцем публикации объявления:

# %%
real_estate['month'] = real_estate['first_day_exposition'].dt.month
real_estate['month'].unique() # Публикация осуществляется ежемесячно с января(1) по декабрь(12)
# Out:
# array([12,  9, 11,  5,  2,  8,  6,  1,  3,  4, 10,  7])

# %% [markdown]
# Столбец с годом публикации объявления:

# %%
real_estate['year'] = real_estate['first_day_exposition'].dt.year
real_estate['year'].unique() # перед нами данные за период с 2015 по 2019 годы включительно
# Out:
# array([2018, 2017, 2016, 2019, 2015])

# %% [markdown]
# Столбец с категорией этажности:

# %%
def categorize_floor(row):
    floor = row['floor']
    floors_total = row['floors_total']
    if floor == 1:
        return 'первый'
    if floor == floors_total:
        return 'последний'
    if floor > 1 and floor != floors_total:
        return'другой'
real_estate['floor_category'] = real_estate.apply(categorize_floor, axis=1)

# %% [markdown]
# Cтолбец с расстоянием до центра города в км:

# %%
real_estate['cityCenters_nearest_km'] = (real_estate['cityCenters_nearest']/1000).round(0).astype(int)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# **Задание 4.1**
# Изучим следующие параметры  и построим гистограммы для каждого параметра:
#   - общая площадь;
#   - жилая площадь;
#   - площадь кухни;
#   - цена объекта;
#   - количество комнат;
#   - высота потолков;
#   - этаж квартиры;
#   - тип этажа квартиры («первый», «последний», «другой»);
#   - общее количество этажей в доме;
#   - расстояние до центра города в метрах;
#   - расстояние до ближайшего аэропорта;
#   - расстояние до ближайшего парка;
#   - день и месяц публикации объявления
#
#  Проанализируем построенные гистограммы.

# %%
real_estate['total_area'].hist(bins=50, range = (0,200))
plt.title('Общая площадь')
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Здорово, что ты используешь range, так нагляднее.
#
# </div>

# %% [markdown]
# Наиболее распространены объекты недвижимости с общей площадью от 30 до 60 метров.Больше всего квартир общей площадью 30-49 метров.

# %%
real_estate['living_area'].hist(bins=50, range = (8,120))
plt.title('Жилая площадь')
plt.show()

# %% [markdown]
# Основная часть объектов имеет жилую площадь от 15 до 50 метров.
# При этом среди них наиболее распространены объекты недвижимости с жилой площадью 17-19 метров и 30-35.

# %%
real_estate['kitchen_area'].hist(bins=30)
plt.title('Площадь кухни')
plt.show()

# %% [markdown]
# Большинство квартир имееют площадь кухни от 4 до 15 метров.
# При этомнаиболее распространёнными являются квартиры с площадью кухни 8, 6 и 10-11 метров.

# %%
real_estate['last_price'].hist(bins=50, range =(0, 25000000))
plt.ticklabel_format(style='plain')
plt.title('Цена объектов')
plt.show()

# %% [markdown]
# Основная часть объектов недвижимости варьируется в ценовом диапазоне от 3 до 7 миллионов.
# Больше всего объявлений с ценой около 4 миллионов.

# %%
real_estate['rooms'].hist(bins=30, range=(1,8))
plt.title('Количество комнат')
plt.show()

# %% [markdown]
# Наиболее распространены 1-комнатные и,чуть менее, 2-комнатные квартиры.
# Затем, с отставанием, идут 3-комнатные. И,значительно реже, 4-комнатные.

# %%
real_estate['ceiling_height'].hist(bins=30, range=(2,4))
plt.title('Высота потолков в квартирах')
plt.show()

# %% [markdown]
# Наиболее распространены типовые объекты недвижимости с высотой потолков 2,7 метра. Затем идут объекты эконом-класса с высотой потолков 2,5. Потолки высотой 3 и 3,2 метра встречаются значительно реже.

# %%
real_estate['floor'].hist(bins=30, range=(1,37))
plt.title('Этаж квартиры')
plt.show()

# %% [markdown]
# Очень много объектов, расположено на втором этаже.
# Основная масса оъявлений охватывает объекты, расположившиеся со 2ого по 9ый этаж.

# %%
real_estate['floor_category'].hist(bins=30)
plt.title('Тип этажа квартиры')
plt.show()

# %% [markdown]
# Категория этажа большинства объеков относится к типу Другие. А объектов недвижимости, расположенных на перврм/последнем этаже - значительно меньше.

# %%
real_estate['floors_total'].hist(bins=30)
plt.title('Общее количество этажей в доме')
plt.show()

# %% [markdown]
# Большинство продаваемых объектов недвижимости расположено в 5-этажных домах, затем идут 9-этажки. Следующая, выделяющаяся категория, это 12-и, 16-и и 27-этажные здания.

# %%
real_estate['cityCenters_nearest'].hist(bins=30,range = (0,55000))
plt.title('Расстояние до центра города в метрах')
plt.show()

# %% [markdown]
# Основная часть объектов расположена на расстоянии от 2 до 18 км до центра города.
# Больше всего объектов расположено на расстоянии 11 до 17 км до центра города.

# %%
real_estate['airports_nearest'].hist(bins=30, range = (0,77000))
plt.title('Расстояние до ближайшего аэропорта')
plt.show()

# %% [markdown]
# Основная часть объектов расположена на расстоянии от 10 до 52 км до ближайшего аэропорта.
# Больше всего объектов расположено на расстоянии 12, 19, 24 км до ближайшего аэропорта.

# %%
real_estate['parks_nearest'].hist(bins=30, range = (0,3000))
plt.title('Расстояние до ближайшего парка')
plt.show()

# %% [markdown]
# Основная часть объектов расположена на расстоянии от 0 до 800 м. до ближайшего парка.
# Больше всего объектов расположено в пределах  полукилометра до ближайшего парка.

# %%
real_estate['month'].hist(bins=30)
plt.title('Месяц публикации объявления')
plt.show()

# %% [markdown]
# Торговля кипит во все месяцы. Но меньше всего объявлений выкладывают в мае и январе. Очевидно, во времена длинных нерабочих дней наблюдается затишье с продажами недвижимости.Месяцы с наибольшей активностью - февраль, ноябрь, март, октябрь, сентябрь.

# %%
real_estate['weekday'].hist(bins=30)
plt.title('День недели публикации объявления')
plt.show()

# %% [markdown]
# Гистограмма показывет, что меньше всего объявлений публикуется в выходные дни - субботу и воскресенье.
# Это обусловлено тем, что многие агенства недввижимости не работают в выходные, а простые люди - также  хотят отдохнуть от всех забот.

# %% [markdown]
# **Задание 4.2**
# Изучим как быстро продавались квартиры

# %%
real_estate['days_exposition'].hist(bins=30)
plt.title('Количество дней на экспозиции')
plt.show()

# %%
real_estate['days_exposition'].mean()
# Out:
# 104.2230791875184

# %%
real_estate['days_exposition'].median()
# Out:
# 73.0

# %%
real_estate['days_exposition'].describe()
# Out:
# count   16985.00
# mean      104.22
# std        89.41
# min         1.00
# 25%        37.00
# 50%        73.00
# 75%       153.00
# max       365.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, верно интерпретированы данные из графика и .describe() 😃
#
# </div>

# %% [markdown]
# Медианное значение времени продажи квартиры - 73 дня, среднее - 104.
# Быстрыми можно считать продажи в течение первых 10 дней.Возможно, это объявления о срочной продаже по хорошей цене. И таких объявлений много. Долгими продажами можно считать объекты, продающиеся свыше 220 дней. Объектов, относящихся к долгим продажам, значительно меньше, чем объектов, относящихся к быстрым продажам.Возможно хозяева квартиры поставили завышенную цену и не хотят уступать.Или же у объекта имеются какие то "деффеты":проблемы с документами на собственность, соседство с хим.объектом и т.д.

# %% [markdown]
# **Задание 4.3**
#
# Рассмотрим, какие факторы больше всего влияют на стоимость объекта?
#
# Проверим, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
#
# Построим графики, которые покажут зависимость цены от указанных выше параметров.

# %%
price_and_total_area = real_estate.pivot_table(index='total_area', values= 'last_price', aggfunc='median').copy()
price_and_total_area.plot(grid=True, figsize=(12, 5), style = 'o',y='last_price',alpha=0.05)
plt.ticklabel_format(style='plain')
plt.title('Соотношение цены и общей площади')
plt.show()

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Обрати внимание на то, что на данном графике все точки слились в большое пятно.
#
# Повтори, пожалуйста, еще раз в спринт «Исследовательский анализ данных» тему «Взаимосвязь данных» урок «Корреляция» и попробуй добавить параметр прозрачности.
#
# Поправь, пожалуйста, тут и на всех подобных графиках ниже.
#
#
# </div>

# %% [markdown]
# <div class="alert-info">
# Валентин, действительно, у меня на графиках такого типа получился один большой пельмень из точек)
# Здесь и на всех аналогичных графиках добавляю параметр прозрачности.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %%
real_estate.query('2000000 < last_price < 6000000 and total_area < 100').plot(x='last_price', y='total_area', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и общей площади')
plt.show()

# %%
real_estate['last_price'].corr(real_estate['total_area']) #корреляция цены и общей площади
# Out:
# 0.7604417954517155

# %% [markdown]
# Анализ показывает, что с ростом общей площади растёт и цена квартиры, особенно ярко это выражено у объектов с общей площадью до 100 квадратных метров. Коэфиициент корреляции, равный 0.76 говорит о том, что взаимосвязь стоимости квартиры и общей площади  очень сильна. Диаграмма рассеивания показывает, что больше всего квартир со стоимостью от 2,9 до 3,45 млн. и общей площадью порядка 33 квадратных метров.

# %%
price_and_living_area = real_estate.pivot_table(index='living_area', values= 'last_price', aggfunc='median').copy()
price_and_living_area.plot(grid=True, figsize=(12, 5), style = 'o',y='last_price',alpha=0.05) 
plt.ticklabel_format(style='plain')
plt.title('Соотношение цены и жилой площади')
plt.show()

# %%
real_estate.query('2000000 < last_price < 6000000 and living_area < 60').plot(x='last_price', y='living_area', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и жилой площади')
plt.show()

# %%
real_estate['last_price'].corr(real_estate['living_area']) #корреляция цены и жилой площади
# Out:
# 0.6569466747272582

# %% [markdown]
# Анализ показывает, что с ростом жилой площади растёт и цена квартиры, особенно ярко это выражено у объектов с жилой площадью до 60 квадратных метров. Коэфиициент корреляции, равный 0.66 говорит о том, что взаимосвязь этих факторов также сильна, но  менее выражена, чем взаимосвязь общей площади и цены. Диаграмма рассеивания показывает, что больше всего квартир со стоимостью от 2,9 до 3,6 млн. и жилой площадью порядка 18 квадратных метров.

# %%
price_and_kitchen_area = real_estate.pivot_table(index='kitchen_area', values= 'last_price', aggfunc='median').copy()
price_and_kitchen_area.plot(grid=True, figsize=(12, 5), style = 'o',y='last_price',alpha=0.05) 
plt.ticklabel_format(style='plain')
plt.title('Соотношение цены и площади кухни')
plt.show()

# %%
real_estate.query('2000000 < last_price < 6000000 and kitchen_area < 20').plot(x='last_price', y='kitchen_area', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и площади кухни')
plt.show()

# %%
real_estate['last_price'].corr(real_estate['kitchen_area']) #корреляция цены и площади кухни
# Out:
# 0.5756571740728773

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Полный вывод, правильно посчитана и интерпретирована корреляция.
#
# </div>

# %% [markdown]
# Анализ показывает, что с ростом площади кухни растёт и цена квартиры,но выражено это у объектов с площадью кухни до 15 квадратных метров. Коэфиициент корреляции, равный 0.58 говорит о том, что взаимосвязь этих факторов также сильна, но  площадь кухни влияет на цену в меньшей степени, чем общая и жилая площадь. Диаграмма рассеивания показывает, что больше всего квартир со стоимостью: от 3.6 до 4 млн., 4.5 млн. и площадью кухни 7,5 квадратных метров.

# %%
#линейный график для количества комнат не актуален
#price_and_rooms = real_estate.pivot_table(index='rooms', values= 'last_price', aggfunc='median').copy()
#price_and_rooms.plot(grid=True, figsize=(12, 5), style = '-o',y='last_price') 
#plt.ticklabel_format(style='plain')
#plt.title('Соотношение цены и количества комнат')
#plt.show()

# %%
real_estate.query('2000000 < last_price < 6000000').plot(x='last_price', y='rooms', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и количества комнат')
plt.show()

# %% [markdown]
# <div class="alert-info">
# Хотя количество комнат написано цифрами - это категориальная переменная, а не количественная. Поэтому считать корреляцию не буду. И  добавлю столбчатую диаграмму.
# </div>

# %%
#real_estate['last_price'].corr(real_estate['rooms']) #не актуально

# %%
rooms_and_price = real_estate.pivot_table(index='rooms',values='last_price', aggfunc='median').copy()
rooms_and_price
# Out:
#        last_price
# rooms
# 0         2700000
# 1         3550000
# 2         4650000
# 3         5900000
# 4         7500000
# 5        11150000
# 6        12995000
# 7        15000000
# 8        22190000

# %%
rooms_and_price.plot.bar(grid=True, figsize=(12, 6), y='last_price') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и количества комнат')
plt.show()

# %% [markdown]
# <div class="alert-info">
# Анализ показывает, что с ростом количества комнат растёт и цена квартиры. Диаграмма рассеивания показывает, что больше всего 1-комнатных квартир со стоимостью: от 3.2 до 3.6 млн.
# </div>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Считать корреляцию для категориальных данных не корректно, так как корреляция применима только к линейным зависимостям, а зависимость от категории этажа, дня недели, месяца или года не линейна, чаще всего там есть сезонность. Тут лучше просто построить столбчатую диаграмму по медианам.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %%
floor_category_and_price = real_estate.pivot_table(index='floor_category',values='last_price', aggfunc='median').copy()
floor_category_and_price
# Out:
#                 last_price
# floor_category
# другой             4550000
# первый             3750000
# последний          4100000

# %%
floor_category_and_price.plot.bar(grid=True, figsize=(12, 5), y='last_price') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и категории этажа квартиры')
plt.show()

# %% [markdown]
# Анализ показывает, что дешевле всего квартиры на первом этаже - их медианная цена 3.85 млн. Квартиры на последнем этаже ценятся больше - их медианная цена 4.15 млн. И, конечно же, дороже всего квартиры с категорией этажа Другие  - 4.7 млн.

# %%
#линейный график для дней недели не актуален
#price_and_weekday = real_estate.pivot_table(index='weekday', values= 'last_price', aggfunc='median').copy()
#price_and_weekday.plot(grid=True, figsize=(12, 5), style = '-o',y='last_price') 
#plt.ticklabel_format(style='plain')
#plt.title('Соотношение цены и дня недели размещения объявления')
#plt.show()

# %%
real_estate.query('2000000 < last_price < 6000000').plot(x='last_price', y='weekday', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и дня недели публикации')
plt.show()

# %% [markdown]
# <div class="alert-info">
# Хотя день недели прописан цифрами - это категориальная переменная, а не количественная. Поэтому считать корреляцию не буду. И  добавлю столбчатую диаграмму.
# </div>

# %%
weekday_and_price = real_estate.pivot_table(index='weekday',values='last_price', aggfunc='median').copy()
weekday_and_price
# Out:
#          last_price
# weekday
# 0           4400000
# 1           4450000
# 2           4400000
# 3           4400000
# 4           4350000
# 5           4490000
# 6           4300000

# %%
weekday_and_price.plot.bar(grid=True, figsize=(12, 10), y='last_price') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и дня недели')
plt.show()

# %%
# real_estate['last_price'].corr(real_estate['weekday']) #не актуально

# %% [markdown]
# Взаимосвзяь цены квартиры и дня недели ничтожно маленькая. Но всё же можно отметить, что к концу недели медианная стоимость квартир немного снижается и  самая низкая цена приходится на воскресенье; большинство объявлений о продаже квартир было размещено в пятницу и медианная стоимость таких квартир составляла около 3,5 млн.

# %%
#линейный график для месяцев не актуален
#price_and_month = real_estate.pivot_table(index='month', values= 'last_price', aggfunc='median').copy()
#price_and_month.plot(grid=True, figsize=(12, 5), style = '-o',y='last_price') 
#plt.ticklabel_format(style='plain')
#plt.title('Соотношение цены и месяца размещения объявления')
#plt.show()

# %%
real_estate.query('2000000 < last_price < 6000000').plot(x='last_price', y='month', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и месяца публикации')
plt.show()

# %% [markdown]
# <div class="alert-info">
# Хотя месяц и  прописан цифрами - это категориальная переменная, а не количественная. Поэтому считать корреляцию не буду. И  добавлю столбчатую диаграмму.
# </div>

# %%
month_and_price = real_estate.pivot_table(index='month',values='last_price', aggfunc='median').copy()
month_and_price
# Out:
#        last_price
# month
# 1         4400000
# 2         4400000
# 3         4350000
# 4         4450000
# 5         4400000
# 6         4200000
# 7         4400000
# 8         4499000
# 9         4500000
# 10        4395000
# 11        4500000
# 12        4350000

# %%
month_and_price.plot.bar(grid=True, figsize=(12, 10), y='last_price') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и месяца')
plt.show()

# %%
#real_estate['last_price'].corr(real_estate['month']) #не актуально

# %% [markdown]
# Взаимосвязь цены и месяца публикации ничтожно мала. Можно отметить, что в июне медианное значение цены квартиры становится наименьшим в году. Также можно отметить, что большинство объявлений подают в октябре и ноябре.

# %%
real_estate.query('2000000 < last_price < 6000000').plot(x='last_price', y='year', kind='hexbin', \
gridsize=20, figsize=(12, 6), sharex=False, grid=True)
plt.ticklabel_format(style='plain')
plt.title('Cоотношение цены и года публикации')
plt.show()

# %%
#линейный график для годов не актуален
#price_and_year = real_estate.query('year > 2016').pivot_table(index='year', values= 'last_price', aggfunc='median').copy()
#price_and_year.plot(grid=True, figsize=(12, 5), style = '-o',y='last_price') 
#plt.ticklabel_format(style='plain')
#plt.title('Соотношение цены и года размещения объявления')
#plt.show()

# %%
#real_estate['last_price'].corr(real_estate['year']) #не актуально

# %% [markdown]
# <div class="alert-info">
# Хотя год и  прописан цифрами - это категориальная переменная, а не количественная. Поэтому считать корреляцию не буду. И  добавлю столбчатую диаграмму.
# </div>

# %%
year_and_price = real_estate.pivot_table(index='year',values='last_price', aggfunc='median').copy()
year_and_price
# Out:
#       last_price
# year
# 2015  4895000.00
# 2016  4394153.50
# 2017  4300000.00
# 2018  4400000.00
# 2019  4700000.00

# %%
year_and_price.plot.bar(grid=True, figsize=(12, 10), y='last_price') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и года')
plt.show()

# %% [markdown]
# Диаграмма рассеивания показывает, что объявлений за 2015 год и 2016- очень мало и значение их медианной цены при такой малой выборке будет не показательным.
# Так же можно отметить, что начиная с 2017 года идёт незначительное постоянное увеличение стоимости объектов недвижимости.

# %% [markdown]
# **Общий вывод по заданию 4.3**
#
# Анализ показывает,что наиболее значимым фактором, влияющим на цену квартиры, являются общая площадь. Также важными факторами ценообразования являются жилая площадь, площадь кухни, количество комнат и категория этажа.

# %% [markdown]
# **Задание 4.4**
# Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.Определим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
price_of_square_meter_by_locality = real_estate.pivot_table(index='locality_name',values='price_of_square_meter', \
aggfunc=['count','mean']).copy()
price_of_square_meter_by_locality.columns=['count','mean_price_for_square_metr']
top_10_locality_areas = price_of_square_meter_by_locality.sort_values(by='count',ascending=False).head(10).copy()
top_10_locality_areas.sort_values(by='mean_price_for_square_metr',ascending=False).head(10)
# Out:
#                    count  mean_price_for_square_metr
# locality_name
# Санкт-Петербург    11158                   107462.00
# Пушкин               255                   100500.05
# деревня Кудрово      258                    92762.86
# поселок Парголово    262                    89081.06
# поселок Мурино       488                    86018.38
# поселок Шушары       361                    78167.50
# Колпино              274                    74504.20
# Всеволожск           286                    69033.86
# Гатчина              221                    68209.82
# Выборг               178                    57057.36

# %% [markdown]
# <div class="alert-info">
# Удалю лишний столбец и построю столбчатую диаграмму.
# </div>

# %%
top_10_locality_areas.drop(columns = ['count'],axis = 1).sort_values(by='mean_price_for_square_metr',ascending=False)
# Out:
#                    mean_price_for_square_metr
# locality_name
# Санкт-Петербург                     107462.00
# Пушкин                              100500.05
# деревня Кудрово                      92762.86
# поселок Парголово                    89081.06
# поселок Мурино                       86018.38
# поселок Шушары                       78167.50
# Колпино                              74504.20
# Всеволожск                           69033.86
# Гатчина                              68209.82
# Выборг                               57057.36

# %%
top_10_locality_areas.plot.bar(grid=True, figsize=(12, 10), y='mean_price_for_square_metr') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Соотношение цены и населённого пункта')
plt.show()

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Построй, пожалуйста, столбчатую диаграмму или ящики с усами по топ 10 населенным пунктам.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>

# %% [markdown]
# Среди 10 крупнейших населённых пунктов Ленинградской области, самая высокая средняя цена квадратного метра - в Санкт-Петербурге, а самая низкая - в Выборге.

# %% [markdown]
# **Задание 4.5**
# Выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. Опишем, как стоимость объектов зависит от расстояния до центра города.

# %%
price_for_square_metr_and_city_centr = real_estate.query('locality_name == "Санкт-Петербург" and \
cityCenters_nearest_km != 78').pivot_table(index='cityCenters_nearest_km',
values= 'price_of_square_meter', aggfunc='mean').copy()
price_for_square_metr_and_city_centr.plot(grid=True, figsize=(12, 5), style = '-o',y='price_of_square_meter') 
plt.ticklabel_format(style='plain')
plt.title('Соотношение средней цены за метр квадратный и удалённости от центра СПБ в километрах')
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Супер, корректно выделены квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислена средняя цена каждого километра.
#
# </div>

# %% [markdown]
# Анализ наглядно демонстрирует, что чем ближе квартира к центру города, тем выше средняя цена квадратного метра.
# Из общего графика выбиваются квартиры, расположенные в районе 27 километров от центра. Возможно, это какой-то элитный ЖК.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Проведено исследование с целью выявления  особенностей и закономерностей, которые существуют на рынке недвижимости Ленинградской области за 2014 - 2019 годы.
#
# Для подготовки к  исследованию была проведена предобработка данных:
# - Изменён тип данных в столбцах
# - Заполнены пропущенные значения там, где это возможно
# - Устанены неявные дубликаты
# - Аномальные значения заменены на корректные там, где это возможно. В противном случае строки с сомнительными данными были удалены.
# - Для дальнейшего исследования в датафрейм были добавлены столбцы с ценой квадратного метра, днём недели/месяцем/годом публикации,типом этажа квартиры (первый/последний/другой),расстоянием до центра города в километрах.
#
# Изучив представленные данные и построив по ним гистограммы было установлено:
# - Большинство представленных квартир имеют общую площадь 30-49 метров.
# - Большинство представленных квартир имеют жилую площадь 17-19 метров.
# - Большинство представленных квартир имеют площадь кухни 8, 6 и 10-11 метров.
# - Больше всего объявлений с ценой около 4 миллионов.
# - Наиболее распространены 1-комнатные и,чуть менее, 2-комнатные квартиры.
# - Наиболее распространены типовые объекты недвижимости с высотой потолков 2,7 метра. Затем - 2,5 метра.
# - Большинство продаваемых квартир расположено не на первом/последнем этажах.
# - Большинство продаваемых объектов недвижимости расположено в 5-этажных домах, затем идут 9-этажки.
# - Основная часть объектов расположена на расстоянии от 2 до 18 км до центра города.
# - Основная часть объектов расположена на расстоянии от 10 до 52 км до ближайшего аэропорта.
# - Основная часть объектов расположена на расстоянии от 0 до 800 м. до ближайшего парка.
# - Меньше всего объявлений выкладывают в мае и январе.Месяцы с наибольшей активностью - февраль, ноябрь, март, октябрь, сентябрь.
# -Меньше всего объявлений публикуется в выходные дни - субботу и воскресенье.
# -Медианное значение времени продажи квартиры - 73 дня, среднее - 104. Быстрыми можно считать продажи в течение первых 10 дней.Возможно, это объявления о срочной продаже по хорошей цене. И таких объявлений много. Долгими продажами можно считать объекты, продающиеся свыше 220 дней. Объектов, относящихся к долгим продажам, значительно меньше, чем объектов, относящихся к быстрым продажам
#
# В ходе исследования было проверено, влияют ли на цену следующие факторы:
# 1. общая площадь;
# 2. жилая площадь;
# 3. площадь кухни;
# 4. количество комнат;
# 5. этаж, на котором расположена квартира (первый, последний, другой);
# 6. дата размещения (день недели, месяц, год);
# 7. в каком населённом пункте Ленинградской области расположена квартира;
# 8. расстояние до центра города в квартирах Санкт-Петербурга.
#
# В результате исследования удалось выявить следующие зависимости.
# 1. С ростом общей площади растёт и цена квартиры, особенно ярко это выражено у объектов с общей площадью до 100 квадратных метров.Большинство квартир общей площадью 34 метра стоят в районе 3.1 млн, а с общей площадью 42 метра - уже в районе 4 млн. Коэфиициент корреляции, равный 0.76 говорит о том, что взаимосвязь стоимости квартиры и общей площади  очень сильна.
# 2. С ростом жилой площади растёт и цена квартиры, особенно ярко это выражено у объектов с жилой площадью до 60 квадратных метров. Большинство квартир с жилой площадью 18 метров стоят в диапазоне от 2,9 до 3.7 млн, а с жилой площадью 40 метров  стоят уже от 5 млн. Коэфиициент корреляции, равный 0.66 говорит о том, что взаимосвязь этих факторов также сильна, но  менее выражена, чем взаимосвязь общей площади и цены.
# 3. С ростом площади кухни растёт и цена квартиры,но выражено это у объектов с площадью кухни до 15 квадратных метров. Большинство квартир с площадью кухни  6  метров стоят в диапазоне от 2,9 до 3.6 млн, а с площадью кухни 10 метров  стоят уже от 3.6 до 4.6 млн. Коэфиициент корреляции, равный 0.58 говорит о том, что взаимосвязь этих факторов также сильна, но  площадь кухни влияет на цену в меньшей степени, чем общая и жилая площадь.
# 4. С ростом количества комнат растёт и цена квартиры. Ярко выражена  взаимосвязь этих факторов.Большинство однокомнатных квартир продавались по цене от до 2.9 до 3.6 млн., а двухкомнатные стоят уже в районе 3.9 млн.
# 5. Категория этажа (первый,последний, другой) также тесно связана с ценой квартиры. Так, средняя цена квартиры на первом этаже на 18% ниже аналога на среднем этаже. А средняя цена квартиры на последнем этаже на 19% ниже аналога на среднем этаже.
# 6. Взаимосвязь цены квартиры и дня недели/месяца/года публикации - очень незначительна.
# 7. Выявлено, что среди 10 крупнейших населённых пунктов Ленинградской области, самая высокая средняя цена квадратного метра - в Санкт-Петербурге (107462), а самая низкая - в Выборге(57057).
# 8. Анализ показал, что, чем ближе квартира к центру города, тем выше средняя цена квадратного метра. Цена квартир в радиусе 10 километров от центра варьируется в радиусе от 110 до 132 тысяч за метр квадратный. А квартиры в радиусе от 10 до 20 километров от центра уже представлены в ценавом диапазоне от до 100 до 110 тысяч за метр квадратный.

# %% [markdown]
# В результате исследования было выявлено, что рынок недвижимости в Ленинградской области за период 2015-2019 годов был в основном представлен квартирами в областной столице в бюджетном сегменте:1-2 комнатные квартиры общей площадью 30-49 метров со стандартной высотой потолков 2.7 метра и стоимостью в районе 4 миллионов. Большинство объектов недвижмости расположены в 5 и 9-этажных зданиях. Приятно отметить,что подавляющее большинство квартир расположены в радиусе пешей доступности до ближайшего парка(в пределах 800 метров).
#
# Анализ базы данных недвижимости показал, что ниболее значимыми факторами ценообразования являются населённый пункт(СПБ), количество комнат, общая и жилая площадь, площадь кухни, категория этжа и удалённость от центра города.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты.
#
# Скорректируй их, пожалуйста, после того как исправишь недочеты.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# </div>
