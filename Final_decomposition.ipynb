# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Привет, Катя! Поздравляю с достижением финального спринта!!!</b>
#
# Меня зовут Петр Раздобреев и я буду проверять твою работу. Попробую помочь сделать тебе её еще лучше! В Практикуме принято общени на ты, но если это дискомфортно, то сообщи об этом)
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>☁️Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️ Так выделены небольшие замечания.Такие замечания в проекте допустимы, это пространство для улучшений в будущем.
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️Так я выделяю успешные идеи.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# # Проектная работа "Телеком — Определение неэффективных операторов"

# %% [markdown]
# # 1.Предобработка данных

# %% [markdown]
# ## 1.1. Исследовать пропущенные значения. Заменить пропущенные значения / объяснить почему этого делать не стоит и удалить строки с пропусками

# %% [markdown]
# ## 1.2. Исследовать соответствие типов, привести столбцы к новому типу

# %% [markdown]
# ## 1.3. Исследовать дубликаты

# %% [markdown]
# ## 1.4. Удалить дубликаты

# %% [markdown]
# ## 1.5. Проверить корректность наименований колонок и, при необходимости, переименовать.

# %% [markdown]
# ## 1.6.Объединить датафреймы telecom_df и clients и для дальнейшего анализа оставим тоько данные без учёта внутренних звонков операторов друг другу.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Отличный этап предобработки, нет вопросов </div>

# %% [markdown]
# # 2.Исследовательский анализ данных

# %% [markdown]
# ## 2.1. Для колл-центров  или операторов введём категории: специализируется на входящих/исходящих звонках/универсальный.

# %% [markdown]
# ## 2.2. Создадим столбец, где будет считаться время одного звонка без учёта времени ожидания: 1_call_duration = call_duration/calls_count

# %% [markdown]
# ## 2.3. Создадим столбец, где будет считаться время ожидания для одного звонка: 1_call_expectation_time = (total_call_duration - call_duration)/calls_count

# %% [markdown]
# ## 2.4. Для каждого оператора найдём соотношение принятых и пропущенных звонков, определим среднее время ожидания ответа оператора на один звонок,

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Рекомендовал бы не выносить универсальную категорию, чтобы не увеличивать число переменных

# %% [markdown]
# # 3. Определите неэффективных операторов:

# %% [markdown]
# ## 3.1. Для операторов, работающих со входящими звонками: среди не новичков найдём операторов, у которых  количество пропущенных входящих вызовов больше определённого значения  (например, больше, чем  в среднем по выборке или выберу и обосную   какое то конкретное число)

# %% [markdown]
# ## 3.2. Для операторов, работающих со входящими звонками: среди не новичков найдём операторов, у которых  время ожидания ответа (ASA) при входящих внешних вызовах больше определённого значения (напрмер, больше, чем в среднем по выборке или выберу и обосную какое-то конкректное число)

# %% [markdown]
# ## 3.3. Для операторов, работающих на исходящих звонках,  среди не новичков найдём операторов, у которых  количество исходящих вызовов меньше определённого значения(напрмер, меньше, чем в среднем по выборке или выберу и обосную  какое-то конкретное число)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>⛅️
#
# * Хотелось бы конкретики по выбору числа границы, как к нему подходить, но ладно добавлю только, что не рекомендую опираться на перцентили, так как данные считаем по не самым эффективным операторам
# * Деление на новичков и не новичков для различия в границах эффективности можно вводить, но я предполагал, что это будет утчено рассматривая не абсолютное число звонков например, а число звонков в день
# </div>

# %% [markdown]
# # 4.Проверка гипотез

# %% [markdown]
# ## 4.1. Среднее время разговора операторов,пользующихся  тарифом «А» и «В» различается.

# %% [markdown]
# ## 4.2. Операторы, работающие на обзвонах, обрабатывают в день больше звонков, чем операторы,работающие на входящих звонках.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Гипотезы принимаются, удачи в реализации проекта!

# %% [markdown]
# # 5. Подготовка презентации

# %% [markdown]
# # 6. Дашборд
