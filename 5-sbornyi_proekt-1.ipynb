# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# Привет!👋
#
#
# Меня зовут Андрей Саввин, я стал ревьюером твоего проекта)). Предлагаю перейти на 'ты', но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста не удаляй мои комментарии, они очень пригодятся для нашей работы в случае повторной проверки проекта.
#
# Если у тебя появляются вопросы к моим комментариям, поставь под ними свои комментарии, лучше выделить их цветом или обозначить любым удобным тебе способом, главное чтобы твои комментарии визуально отличались от моих, тогда мы не запутаемся))
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!</b> 🏆:
# В случае, если решение на отдельном шаге является полностью правильным.
#
# </div>
#
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации</b>🔎: В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
#
# </div>
#
#
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>На доработку</b>🤔: В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
#
#
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
# **🔎В конце блокнота кликабельные ссылки на моменты где нужны правки, для твоего удобства**

# %% [markdown]
# **1. Откроем файл с данными и изучим общую информацию**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
games = pd.read_csv('/datasets/games.csv')

# %%
games.head(100)
# Out:
#                                       Name Platform  Year_of_Release  \
# 0                               Wii Sports      Wii           2006.0
# 1                        Super Mario Bros.      NES           1985.0
# 2                           Mario Kart Wii      Wii           2008.0
# 3                        Wii Sports Resort      Wii           2009.0
# 4                 Pokemon Red/Pokemon Blue       GB           1996.0
# ..                                     ...      ...              ...
# 95  Crash Bandicoot 2: Cortex Strikes Back       PS           1997.0
# 96     Super Smash Bros. for Wii U and 3DS      3DS           2014.0
# 97                    Super Mario Galaxy 2      Wii           2010.0
# 98                     Super Mario Bros. 2      NES           1988.0
# 99               Call of Duty: Black Ops 3     XOne           2015.0
#
#            Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games['Rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
games['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
games['Critic_Score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %%
games['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
games['Genre'] = games['Genre'].str.lower()

# %%
games['Year_of_Release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
games['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>  1 Все отлично!</b> 🏆:
#
# Все верно.
#
# </div>

# %% [markdown]
# **2. Подготовка данных**

# %% [markdown]
# **2.1.** Заменим названия столбцов:

# %%
games.columns = games.columns.str.lower()

# %%
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# **2.2.** Преобразуем данные в нужные типы с указанием, в каких столбцах изменён тип данных и почему:

# %% [markdown]
# **2.2.1.** Изменим тип данных в столбце user_score на float, ведь оценка пользователей это числовой показатель. В списке уникальных значений столбца значится некое 'tbd', полагаю, что это опечатка и заменю его на Nan.

# %%
games['user_score'].unique() #Изучим список уникальных значений
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
def replace_wrong_user_score(wrong_user_score, right_user_score): # Избавимся от значения 'tbd'
    games['user_score'] = games['user_score'].replace(wrong_user_score, right_user_score)
replace_wrong_user_score('tbd', np.NaN)

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
 games['user_score'] =  games['user_score'].fillna(value= '77.7') #поставим заглушку вместо nan

# %%
games['user_score'].unique() #убедимся, что в списке уникальных значений столбца больше нет tbd и nan
# Out:
# array(['8', '77.7', '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3',
#        '7.4', '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8',
#        '3.2', '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3',
#        '4.3', '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
games['user_score'] = pd.to_numeric(games['user_score'],errors='coerce') #Изменим тип данных

# %%
games['user_score'].unique() #посмотрим что получилось
# Out:
# array([ 8. , 77.7,  8.3,  8.5,  6.6,  8.4,  8.6,  7.7,  6.3,  7.4,  8.2,
#         9. ,  7.9,  8.1,  8.7,  7.1,  3.4,  5.3,  4.8,  3.2,  8.9,  6.4,
#         7.8,  7.5,  2.6,  7.2,  9.2,  7. ,  7.3,  4.3,  7.6,  5.7,  5. ,
#         9.1,  6.5,  8.8,  6.9,  9.4,  6.8,  6.1,  6.7,  5.4,  4. ,  4.9,
#         4.5,  9.3,  6.2,  4.2,  6. ,  3.7,  4.1,  5.8,  5.6,  5.5,  4.4,
#         4.6,  5.9,  3.9,  3.1,  2.9,  5.2,  3.3,  4.7,  5.1,  3.5,  2.5,
#         1.9,  3. ,  2.7,  2.2,  2. ,  9.5,  2.1,  3.6,  2.8,  1.8,  3.8,
#         0. ,  1.6,  9.6,  2.4,  1.7,  1.1,  0.3,  1.5,  0.7,  1.2,  2.3,
#         0.5,  1.3,  0.2,  0.6,  1.4,  0.9,  1. ,  9.7])

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>2.2.1 Некоторые замечания и рекомендации</b>🔎:
#
# По идее ,errors='coerce' позволил бы преобразовать tbd в nan, тк не смог бы преобразовать значение в int, а так все корректно.
#
# </div>

# %% [markdown]
# **2.2.2.** Изменим тип данных в столбце year_of_release на целочисленный, избавившись при этом от строк, где значения этого столбца не заполнены. Считаю это обоснованным, поскольку таких строк ничтожно мало, а год выпуска - важный фактор при ислледовании.

# %%
 games  = games.dropna(axis='index', subset=['year_of_release']).reset_index(drop=True).copy()

# %%
 games['year_of_release'] =  games['year_of_release'].astype(int)

# %%
games.info() #убедимся,что изменился тип данных в 2 столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16446 entries, 0 to 16445
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16446 non-null  object
#  2   year_of_release  16446 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16446 non-null  float64
#  5   eu_sales         16446 non-null  float64
#  6   jp_sales         16446 non-null  float64
#  7   other_sales      16446 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       16446 non-null  float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# **2.3.** Обработаем пропуски.

# %% [markdown]
# Считаю нужным избавиться  от строк, где не заполнены значения в столбцах  name и  genre. Это целесообразно, поскольку таких строк всего 2, а наименование игры и жанр - важный фактор в исследовании.Пропусков в этих столбцах ничтожно мало, а, следовательно, источником возникновения пропуска мог служить человеческий фактор - например, завершить работу без сохранения последнего значения.

# %%
games = games.dropna(axis='index', subset=['name']).reset_index(drop=True).copy()

# %%
games = games.dropna(axis='index', subset=['genre']).reset_index(drop=True).copy()

# %% [markdown]
#  В списке уникальных значений столбца rating есть значения 'E10+' и 'K-A'.Это две записи одной и той же возрастной группы: изначальный термин "K-A" ("Kids to Adults") был переименован в E10+ («Everyone 10 and older»). Поэтому предлагаю переименовать 'K-A' в 'E10+' для  более точного анализа.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>  Все отлично!</b> 🏆:
#
# Все верно, хорошо, что внимательно относишься к деталям.
#
# </div>

# %%
def replace_old_rating(old_rating,new_rating):
    games['rating'] = games['rating'].replace(old_rating,new_rating)
replace_old_rating('K-A','E10+')

# %%
games['rating'].value_counts() #проверим, что в списке уникальных значений столбца rating исчезло значение 'K-A'
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1396
# EC         8
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# <a id = 'r1'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b> На доработку</b>🤔:
#
# Здесь обязательно нужна заглушка 'Unknown' для nan значений столбца rating, тк [дальше](#r11) проводится исследование по жанрам и данных об играх без рейтинга не будет на графиках.

# %% [markdown]
# <div class="alert-info">
# Андрей, в столбце рейтинг уже поставлена "заглушка"  - см. ввод [31].
# </div>

# %%
 games.isna().sum() #посмотрим в каких столбцах у нас остались пропущенные значения
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score            0
# rating             6676
# dtype: int64

# %% [markdown]
# Причиной большого количества пропусков в столбце critic_score,вероятно, является отсутствие оценок со стороны критиков (неоцененные игры), или же эти игры вышли недавно и еще не получили свои оценки. Предлагаю заменить пропуски "заглушкой" и в дальнейшем при анализе исключать строки с этим значением.

# %%
 games['critic_score'] =  games['critic_score'].fillna(value= 777)

# %% [markdown]
# Пропуски в столбце возрастная категория могли возникнуть ввиду того, что организация ESRB ещё не дала своё заключение к какой возрастной категории относить эту игру.Количество пропущенных значений в этой графе слишком велико для того, чтобы  удалить строки с пустым значением в этом столбце. Поэтому, оставим строки с пропусками, заменив пропущенные значения на новую категорию: 'возрастная категория не определена'.

# %%
 games['rating'] =  games['rating'].fillna(value= 'возрастная категория не определена')

# %% [markdown]
# **2.4.** Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец.

# %%
 games['total_sales'] =  games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %% [markdown]
# <a id = 'p2'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b> 2 На доработку</b>🤔:
#
# Нужно [доделать обработку rating](#r1), в остальном все корректно.

# %% [markdown]
# <div class="alert-info">
# Андрей, в столбце рейтинг уже поставлена "заглушка"  - см. ввод [31].
# </div>

# %% [markdown]
# **3. Исследовательский анализ данных**

# %% [markdown]
# **3.1.** Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games_by_year = games.pivot_table(index = 'year_of_release', values = 'name', aggfunc = 'count')
games_by_year.columns=['number_of_games']
games_by_year.head(10)
# Out:
#                  number_of_games
# year_of_release
# 1980                           9
# 1981                          46
# 1982                          36
# 1983                          17
# 1984                          14
# 1985                          14
# 1986                          21
# 1987                          16
# 1988                          15
# 1989                          17

# %%
games_by_year.plot.bar(grid=True, figsize=(12, 10), y='number_of_games') 
plt.ticklabel_format(style='plain', axis='y')
plt.title('Количество выпущенных игр по годам')
plt.show()

# %% [markdown]
# Как видно из графика, с момента зарождения индустрии компьютерных игр, т.е. с 80-ых годов прошлого века количество ежегодно выпускаемых  игр неуклонно росло вплоть до 2008-2009 года.Затем, вплоть до 2013 года включительно фиксируется значительный спад. С 2014 года тенденция резкого ежегодного уменьшения количества игр сменилась постепенным ростом. В 2016 году - опять незначительное снижение.

# %% [markdown]
# **3.2.** Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. Посмотрим за какой характерный срок появляются новые и исчезают старые платформы.

# %%
games_1 = games.query('2002 <= year_of_release <= 2016').reset_index(drop=True).copy()#с 2002г. количество игр в год превысило 800

# %%
platforms_by_years = games_1.pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum')
platforms_by_years
# Out:
# platform           3DS    DC      DS    GBA     GC   N64     PC    PS     PS2  \
# year_of_release
# 2002               NaN  0.29     NaN  74.16  51.81  0.08   8.57  6.67  205.38
# 2003               NaN   NaN     NaN  56.67  50.61   NaN   8.84  2.07  184.31
# 2004               NaN   NaN   17.27  77.91  28.82   NaN  10.39   NaN  211.81
# 2005               NaN   NaN  130.14  33.86  27.62   NaN   4.37   NaN  160.66
# 2006               NaN   NaN  119.81   5.28  11.26   NaN   2.85   NaN  103.42
# 2007               NaN  0.02  146.94   3.40   0.27   NaN   9.28   NaN   75.99
# 2008               NaN  0.04  145.31    NaN    NaN   NaN  12.42   NaN   53.90
# 2009               NaN   NaN  119.54    NaN    NaN   NaN  16.91   NaN   26.40
# 2010               NaN   NaN   85.02    NaN    NaN   NaN  24.28   NaN    5.64
# 2011             63.20   NaN   26.18    NaN    NaN   NaN  35.03   NaN    0.45
# 2012             51.36   NaN   11.01    NaN    NaN   NaN  23.22   NaN     NaN
# ...

# %% [markdown]
# Как видно из сводной таблицы, платформами, с наибольшим объёмом продаж являются: "PS2","DS","Wii","PS3","X360", "PS4","GBA".  Построим для них распределение по годам. Посмотрим за какой характерный срок появляются новые и исчезают старые платформы.

# %%
platforms_by_years_sorted = games_1.query('platform == ["PS2","DS","Wii","PS3","X360", "PS4","GBA"]'). \
pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum'). \
plot.bar(grid=True, figsize=(15, 9))
plt.title('Продажи платформ по годам')
plt.show()

# %%
platforms_by_years_sorted = games_1.query('platform == ["PS2","DS","Wii","PS3","X360", "PS4","GBA"]'). \
pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum'). \
plot(grid=True, figsize=(15, 6))
plt.title('Продажи платформ по годам (график линейной зависимости)')
plt.show()

# %% [markdown]
# <a id = 'r2'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b> 3.5 На доработку</b>🤔:
#
# Для анализа динамики лучше выбрать график линейной зависимости - как следующий в пункте 3.4.

# %% [markdown]
# <div class="alert-info">
# Построен график линейной зависимости.
# </div>

# %% [markdown]
# На графике видно, что платформы, которые в течение исследуемого периода прошли свой жизненный цикла от зарождения и до прекращения существования это: "PS2","DS","Wii","PS3","X360". Рассчитаем точное количество лет их жизненного цикла:

# %%
years_and_platforms = games_1.query('platform == ["PS2","DS","Wii","PS3","X360"]'). \
pivot_table(index='platform',values='year_of_release',aggfunc=('min','max'))
years_and_platforms.columns = ['last_year_of_release','first_year_of_release']
years_and_platforms['life_period'] = years_and_platforms['last_year_of_release'] - years_and_platforms['first_year_of_release']
years_and_platforms
# Out:
#           last_year_of_release  first_year_of_release  life_period
# platform
# DS                        2013                   2004            9
# PS2                       2011                   2002            9
# PS3                       2016                   2006           10
# Wii                       2016                   2006           10
# X360                      2016                   2005           11

# %% [markdown]
# Как видно из графика и из сводной таблицы, даже самые коммерчески успешные  платформы, в среднем, существуют около 10 лет. Очевидно, за это время появляются принципиально новые идеи и разработки, и, разработчики принимают решение о запуске новой платформы. Развитие каждой платформы идёт по нарастающей до определённого пика, затем идёт спад после которго она прекращает своё существование.

# %% [markdown]
# **3.3.** Актуальным периодом для дальнейшего анализа считаю данные за 2015 - 2016 годы. Данные до 2015 года не актуальны, т.к. до этого года наблюдался рост продаж по представленным на рынке платформам, а  с 2015 года мы работаем в условиях снижения количества продаж.Также важно, чтобы в анализе участвовали только актуальные на данный момент платформы.

# %%
games_sorted = games.query('2015 <= year_of_release <= 2016').reset_index(drop=True)

# %% [markdown]
# **3.4.** Посмотрим, какие платформы лидируют по продажам в 2015-2016 годах, растут или падают. Выберем несколько потенциально прибыльных платформ.

# %%
games_sorted.groupby('platform')['total_sales'].sum()
# Out:
# platform
# 3DS      42.92
# PC       13.77
# PS3      20.42
# PS4     188.15
# PSP       0.12
# PSV      10.50
# Wii       1.32
# WiiU     20.95
# X360     13.48
# XOne     86.29
# Name: total_sales, dtype: float64

# %% [markdown]
# Бесспорным лидером по объёму продаж за 2015-2016 годы является платформа PS4.
# Динамику изменений объёмов продаж по годам предлагаю рассмотреть на платформах с суммарным  объёмом продаж свыше 20 млн.проданных копий. Это будут платформы:3DS, PS3, PS4, WiiU и XOne.

# %%
platforms_total_sales_by_year = games_sorted.query('platform == ["PS4","3DS","XOne","PS3","WiiU"]'). \
pivot_table(index='year_of_release', columns = 'platform', values='total_sales', \
 aggfunc='sum').plot(grid=True, figsize=(15, 6))
plt.title('Продажи платформ в 2013-2016 годах')
plt.show()

# %% [markdown]
# У всех лидирующих по продажам платформ с 2015 года наблюдается тенденция к снижению числа продаж.
# Потенциально прибыльными для продаж в 2017 году исходя из графика следует считать платформы: PS4 и затем,с отрывом, XOne.

# %% [markdown]
# **3.5.** Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишем результат.

# %%
games_sorted.boxplot(column='total_sales', by='platform', figsize=(15,7));
plt.ylim(0,1.35)
plt.suptitle('Продажи платформ - ящик с усами')
plt.show()

# %% [markdown]
# <a id = 'r3'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b> 3.5 На доработку</b>🤔:
#
# Нужно 'отсечь' выбросы, плохо видно основное распределение.

# %% [markdown]
# <div class="alert-info">
# График скорректирован: для большей информативности ylim(0,5) заменила на ylim(0,1.35)
# </div>

# %%
games_sorted.groupby('platform')['total_sales'].describe()
# Out:
#           count      mean       std   min    25%    50%     75%    max
# platform
# 3DS       132.0  0.325152  0.798620  0.01  0.030  0.090  0.2325   7.14
# PC        104.0  0.132404  0.209449  0.01  0.020  0.050  0.1425   1.28
# PS3       111.0  0.183964  0.342696  0.01  0.020  0.060  0.1600   2.70
# PS4       301.0  0.625083  1.457063  0.01  0.050  0.120  0.4200  14.63
# PSP         3.0  0.040000  0.034641  0.02  0.020  0.020  0.0500   0.08
# PSV       195.0  0.053846  0.063669  0.01  0.020  0.030  0.0600   0.41
# Wii         5.0  0.264000  0.390487  0.01  0.030  0.150  0.1800   0.95
# WiiU       42.0  0.498810  0.850240  0.01  0.050  0.215  0.5175   4.44
# X360       48.0  0.280833  0.381207  0.01  0.040  0.110  0.3525   1.70
# XOne      167.0  0.516707  0.965940  0.01  0.035  0.130  0.5550   7.39

# %% [markdown]
# Как видно из графика, в продажах у всех платформ наблюдаются выбросы. Это также подтвеждается в описательном методе describe: среднее значение у всех значительно выше медианного.Но выбросы нас интересуют в меньшей степени.
#
# Основным для нашего анализа  будет медианное значение по продажам. Самое большое медианное значение у WiiU, но лидером эту платформу не назовёшь, т.к. общее количество продаж (сount) слишком мало.
#
# Посмотрим на платформы с большим количеством продаж.  По медианному показателю и по значению 3-его квартиля самые высокие показатели - у платформ XOne и PS4, однако общее количество продаж(count), бесспорно больше у PS4. Поэтому, в исследуемом периоде  платформа является бесспорным лидером на рынке компьютерных игр.

# %% [markdown]
# **3.6.** Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постром диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами. Сформулируем выводы.
#
# Для анализа возьму самую коммерчески успешную платформу PS4.

# %%
games_sorted.query('platform == "PS4" and critic_score!=777').plot(x='critic_score', y='total_sales', kind='scatter', \
alpha=0.5, figsize=(16,6), grid=True) #cоздаём выгрузку по платформе-лидеру без заглушек
plt.ticklabel_format(style='plain')
plt.title('Cоотношение оценки критиков и количества продаж по платформе PS4')
plt.show()

# %%
PS4 = games_sorted.query('platform == "PS4" and critic_score !=777 and user_score!=77.7')
PS4_cor_critic_and_sales = PS4['critic_score'].corr(PS4['total_sales'])
PS4_cor_critic_and_sales
# Out:
# 0.3920741369660568

# %% [markdown]
# Как видно из диаграммы рассеивания и из коэффициента корреляции, взаимосвязь между оценками критиков и продажами PS4 имеет место быть - о чём свидетельствует коэффициент корреляции, равный 0.39. Также стоит отметить, что критики не скупятся на хорошие оценки для популярной игры - большинство их оценок находится в диапазоне от 60 до 82 по 100-балльной шкале.

# %%
games_sorted.query('platform == "PS4" and user_score!=77.7').plot(x='user_score', y='total_sales', kind='scatter', \
 alpha=0.5, figsize=(16,6), grid=True) #cоздаём выгрузку по платформе-лидеру без заглушек
plt.ticklabel_format(style='plain')
plt.title('Cоотношение оценки пользователей и количества продаж по платформе PS4')
plt.show()

# %%
PS4_cor_users_and_sales = PS4['user_score'].corr(PS4['total_sales'])
PS4_cor_users_and_sales
# Out:
# -0.06436843081030288

# %% [markdown]
# Как видно из диаграммы рассеивания и из коэффициента корреляции, взаимосвязь между оценками пользователей и продажами ничтожно маленькая и отрицательная. При этом стоит отметить, что PS4 снискала благосклонность пользователей и подавляющее большинство их оценок находится в диапазоне от 5,5 до 8,8 по 10-балльной шкале.
# В целом можно заключить, что оценки критиков сильнее влияют на продажи PS4, чем оценки пользователей.

# %% [markdown]
# **3.7.** Соотнесите выводы с продажами игр на других платформах.

# %%
games_sorted.query('platform != "PS4" and critic_score!=777').plot(x='critic_score', y='total_sales', kind='scatter', \
alpha=0.5, figsize=(16,6), grid=True) #cоздаём выгрузку по остальным актуальным платформам без заглушек
plt.ticklabel_format(style='plain')
plt.title('Cоотношение оценки критиков и количества продаж по остальным платформам')
plt.show()

# %%
other_platforms_df = games_sorted.query('platform != "PS4" and critic_score !=777 and user_score!=77.7')
cor_critic_and_sales_for_other_platforms = other_platforms_df['critic_score'].corr(other_platforms_df['total_sales'])
cor_critic_and_sales_for_other_platforms
# Out:
# 0.29943715597023157

# %% [markdown]
# Взаимосвязь между оценками критиков и продажами по остальным платформам не очень высокая и положительная о чём также говорит коэффициент корреляции 0,29. Как видно из диаграммы рассеивания для остальных платформ критики дают даже больше оценок в диапазоне 80-90 баллов, возможно это проплаченная реклама.

# %%
games_sorted.query('platform != "PS4" and user_score!=77.7').plot(x='user_score', y='total_sales', kind='scatter', \
alpha=0.5, figsize=(16,6), grid=True) #cоздаём выгрузку по остальным актуальным платформам без заглушек
plt.ticklabel_format(style='plain')
plt.title('Cоотношение оценки пользователей и количества продаж по остальным платформам')
plt.show()

# %%
cor_users_and_sales_for_other_platforms = other_platforms_df['user_score'].corr(other_platforms_df['total_sales'])
cor_users_and_sales_for_other_platforms
# Out:
# 0.038586781017981846

# %% [markdown]
# Как видно из диаграммы рассеивания и из коэффициента корреляции, взаимосвязь между оценками пользователей и продажами по остальным платформам ничтожно маленькая. Но эта связь чуть больше, чем у платформы PS4.
# Также наблюдается тенденция, что у менее продаваемых платформ больше пользовательских оценок с низкими рейтингами: от 4 до 5,5    по 10-балльной шкале.
# Можно сделать вывод, что и для PS4 И для остальных платформ, на продажи большее влияние оказывают оценки критиков, чем оценки пользователей.

# %% [markdown]
# **3.8.** Посмотрим на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
games_sorted.pivot_table(index='genre',values='total_sales',aggfunc='median').plot.bar(grid=True, figsize=(15, 6))
plt.title('Продажи игр по жанрам')
plt.show()

# %%
games_sorted.boxplot(column='total_sales', by='genre', figsize=(15,7));
plt.ylim(0,1.75)
plt.suptitle('Продажи игр по жанрам - ящик с усами')
plt.show()

# %% [markdown]
# По столбчатой диаграмме видно, что безусловным лидером продаж являются "стрелялки" - shooter games. Затем идут спортивные и ролевые игры. Обделены вниманием пользователей пазлы и приключения.
# Отбросив выбросы в "ящике с усами" также видно, что медианное значение и значение 3-ьего квартиля стрелялок нахоятся вне досягаемости для остальных жанров.

# %% [markdown]
# <a id = 'r4'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b> 3.8 На доработку</b>🤔:
#
# Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи
# Обязательно нужно построить еще ящик с усами и посмотреть распределения.

# %% [markdown]
# <div class="alert-info">
# Спасибо за ц.у., после замены суммы продаж на медианное значение, картина существенно изменилась. Добавила ящик с усами.
# </div>

# %% [markdown]
# <a id = 'p3'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>  3 На доработку</b>🤔:
#
# Нужно скоректировать графики для лучшей читаемости [тут](#r2) и [тут](#r3), а также [пересмотреть метрику для определения прибыльного жанра](#r4).
#
# В остальном все корректно.

# %% [markdown]
# **4. Составим портрет пользователя каждого региона**.

# %% [markdown]
# **4.1.** Определим для пользователя каждого региона (NA, EU, JP) самые популярные платформы (топ-5). Опишем различия в долях продаж.

# %% [markdown]
# **4.1.1.** Северная Америка.

# %%
na_platforms = games_sorted.pivot_table(index = 'platform', values = 'na_sales', aggfunc = 'sum')
na_platforms.sort_values(by='na_sales',ascending=False)
# Out:
#           na_sales
# platform
# PS4          63.86
# XOne         50.30
# 3DS          10.31
# WiiU          8.86
# X360          8.05
# PS3           5.66
# PC            3.72
# PSV           0.54
# Wii           0.49
# PSP           0.00

# %%
na_top_5_platforms_list = ['PS4','XOne','3DS', 'WiiU', 'X360'] # топ-5 платформ

# %%
na_sales_other_platforms_list = na_platforms.query('platform not in @na_top_5_platforms_list')['na_sales'].sum()
na_sales_other_platforms_list #cуммарные продажи по играм, не входящим в топ-5 платформ
# Out:
# 10.409999999999993

# %%
na_platforms['platform'] = na_platforms.index
na_platforms #сделаем платформу столбцом
# Out:
#           na_sales platform
# platform
# 3DS          10.31      3DS
# PC            3.72       PC
# PS3           5.66      PS3
# PS4          63.86      PS4
# PSP           0.00      PSP
# PSV           0.54      PSV
# Wii           0.49      Wii
# WiiU          8.86     WiiU
# X360          8.05     X360
# XOne         50.30     XOne

# %%
na_platforms.reset_index(drop=True, inplace=True)
na_top_5_platforms = na_platforms.query('platform in @na_top_5_platforms_list').reset_index(drop=True)
na_top_5_platforms #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 платформ
# Out:
#    na_sales platform
# 0     10.31      3DS
# 1     63.86      PS4
# 2      8.86     WiiU
# 3      8.05     X360
# 4     50.30     XOne

# %%
oher_platforms_sales = {'na_sales': 10.409999999999993,'platform':'other'}
na_top_5_platforms_and_other = na_top_5_platforms.append(oher_platforms_sales, ignore_index=True)
na_top_5_platforms_and_other#создадим датафрейм, где помимо топ-5 платформ, будут суммарно отражены продажи по остальным платформам.
# Out:
#    na_sales platform
# 0     10.31      3DS
# 1     63.86      PS4
# 2      8.86     WiiU
# 3      8.05     X360
# 4     50.30     XOne
# 5     10.41    other

# %%
na_top_5_platforms_and_other.plot.bar(grid=True, figsize=(15, 6), x ='platform')
plt.title('Продажи игр по платформам в Северной Америке')
plt.show()

# %%
na_top_5_platforms_and_other['proportion'] = na_top_5_platforms_and_other['na_sales'] / (na_top_5_platforms_and_other['na_sales'].sum())
na_top_5_platforms_and_other #посчитаем долю продаж игр каждой платформы
# Out:
#    na_sales platform  proportion
# 0     10.31      3DS    0.067923
# 1     63.86      PS4    0.420713
# 2      8.86     WiiU    0.058370
# 3      8.05     X360    0.053034
# 4     50.30     XOne    0.331379
# 5     10.41    other    0.068582

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(na_top_5_platforms_and_other['proportion'],labels = na_top_5_platforms_and_other['platform'], \
autopct = '%1.1f%%',shadow= True, \
radius = 1, normalize=True);
plt.title('Доля продаж компьютерных игр по платформам  в Северной Америке')
plt.show()

# %% [markdown]
# В Северной Америке абсолютным лидером продаж является платформа PS4, в 2015-2016 году продано свыше 60 млн.копий игр на данной платформе.
# На долю PS4 приходится 42% всех продаж в данном регионе. Затем идёт XOne с 33%.
# Доля продаж у всех остальных платформ - в диапазоне 5-7% у каждой (7% - это категория в которой несколько платформ с низкими показателями продаж).

# %% [markdown]
# **4.1.2.** Европа.

# %%
eu_platforms = games_sorted.pivot_table(index = 'platform', values = 'eu_sales', aggfunc = 'sum')
eu_platforms.sort_values(by='eu_sales',ascending=False)
# Out:
#           eu_sales
# platform
# PS4          83.54
# XOne         28.10
# PC            9.10
# 3DS           7.39
# PS3           7.30
# WiiU          6.49
# X360          4.21
# PSV           1.08
# Wii           0.73
# PSP           0.00

# %%
eu_top_5_platforms_list = ['PS4','XOne', 'PC','3DS','PS3'] # топ-5 платформ

# %%
eu_sales_other_platforms_list = eu_platforms.query('platform not in @eu_top_5_platforms_list')['eu_sales'].sum()
eu_sales_other_platforms_list #cуммарные продажи по играм, не входящим в топ-5 платформ
# Out:
# 12.509999999999994

# %%
eu_platforms['platform'] = eu_platforms.index
eu_platforms #сделаем платформу столбцом
# Out:
#           eu_sales platform
# platform
# 3DS           7.39      3DS
# PC            9.10       PC
# PS3           7.30      PS3
# PS4          83.54      PS4
# PSP           0.00      PSP
# PSV           1.08      PSV
# Wii           0.73      Wii
# WiiU          6.49     WiiU
# X360          4.21     X360
# XOne         28.10     XOne

# %%
eu_platforms.reset_index(drop=True, inplace=True)
eu_top_5_platforms = eu_platforms.query('platform in @eu_top_5_platforms_list').reset_index(drop=True)
eu_top_5_platforms #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 платформ
# Out:
#    eu_sales platform
# 0      7.39      3DS
# 1      9.10       PC
# 2      7.30      PS3
# 3     83.54      PS4
# 4     28.10     XOne

# %%
oher_platforms_sales_eu = {'eu_sales': 12.509999999999994,'platform':'other'}
eu_top_5_platforms_and_other = eu_top_5_platforms.append(oher_platforms_sales_eu, ignore_index=True)
eu_top_5_platforms_and_other#создадим датафрейм, где помимо топ-5 платформ, будут суммарно отражены продажи по остальным платформам.
# Out:
#    eu_sales platform
# 0      7.39      3DS
# 1      9.10       PC
# 2      7.30      PS3
# 3     83.54      PS4
# 4     28.10     XOne
# 5     12.51    other

# %%
eu_top_5_platforms_and_other.plot.bar(grid=True, figsize=(15, 6), x ='platform')
plt.title('Продажи игр по платформам в Европе')
plt.show()

# %%
eu_top_5_platforms_and_other['proportion']=eu_top_5_platforms_and_other['eu_sales']/(eu_top_5_platforms_and_other['eu_sales'].sum())
eu_top_5_platforms_and_other #посчитаем долю продаж игр каждой платформы
# Out:
#    eu_sales platform  proportion
# 0      7.39      3DS    0.049953
# 1      9.10       PC    0.061511
# 2      7.30      PS3    0.049344
# 3     83.54      PS4    0.564688
# 4     28.10     XOne    0.189942
# 5     12.51    other    0.084561

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(eu_top_5_platforms_and_other['proportion'],labels = eu_top_5_platforms_and_other['platform'], \
        autopct = '%1.1f%%',shadow= True, \
radius = 1, normalize=True);
plt.title('Доля продаж компьютерных игр по платформам  в Европе')
plt.show()

# %% [markdown]
# В Европе лидерские позиции PS4 укрепляются ещё сильнее, в 2015-2016 году продано свыше 80 млн.копий игр на данной платформе.
# В Европе доля PS4 составляет уже  57% от всех продаж.
# А вот охват рынка у  XOne, по сравнению с Северной Америкой, меньше - только 19%.
# Доля продаж игр на остальных платформах находится в диапазоне 5-8% каждая (8% - это категория в которой несколько платформ с низкими показателями продаж).

# %% [markdown]
# **4.1.3.** Япония.

# %%
jp_platforms = games_sorted.pivot_table(index = 'platform', values = 'jp_sales', aggfunc = 'sum')
jp_platforms.sort_values(by='jp_sales',ascending=False)
# Out:
#           jp_sales
# platform
# 3DS          23.55
# PS4          12.05
# PSV           8.41
# PS3           4.97
# WiiU          4.12
# XOne          0.18
# PSP           0.12
# PC            0.00
# Wii           0.00
# X360          0.00

# %%
jp_top_5_platforms_list = ['3DS','PS4','PSV','PS3','WiiU',] # топ-5 платформ

# %%
jp_sales_other_platforms_list = jp_platforms.query('platform not in @jp_top_5_platforms_list')['jp_sales'].sum()
jp_sales_other_platforms_list #cуммарные продажи по играм, не входящим в топ-5 платформ
# Out:
# 0.30000000000000004

# %%
jp_platforms['platform'] = jp_platforms.index
jp_platforms #сделаем платформу столбцом
# Out:
#           jp_sales platform
# platform
# 3DS          23.55      3DS
# PC            0.00       PC
# PS3           4.97      PS3
# PS4          12.05      PS4
# PSP           0.12      PSP
# PSV           8.41      PSV
# Wii           0.00      Wii
# WiiU          4.12     WiiU
# X360          0.00     X360
# XOne          0.18     XOne

# %%
jp_platforms.reset_index(drop=True, inplace=True)
jp_top_5_platforms = jp_platforms.query('platform in @jp_top_5_platforms_list').reset_index(drop=True)
jp_top_5_platforms #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 платформ
# Out:
#    jp_sales platform
# 0     23.55      3DS
# 1      4.97      PS3
# 2     12.05      PS4
# 3      8.41      PSV
# 4      4.12     WiiU

# %%
oher_platforms_sales_jp = {'jp_sales': 0.30000000000000004,'platform':'other'}
jp_top_5_platforms_and_other = jp_top_5_platforms.append(oher_platforms_sales_jp, ignore_index=True)
jp_top_5_platforms_and_other#создадим датафрейм, где помимо топ-5 платформ, будут суммарно отражены продажи по остальным платформам.
# Out:
#    jp_sales platform
# 0     23.55      3DS
# 1      4.97      PS3
# 2     12.05      PS4
# 3      8.41      PSV
# 4      4.12     WiiU
# 5      0.30    other

# %%
jp_top_5_platforms_and_other.plot.bar(grid=True, figsize=(15, 6), x ='platform')
plt.title('Продажи игр по платформам в Японии')
plt.show()

# %%
jp_top_5_platforms_and_other['proportion']=jp_top_5_platforms_and_other['jp_sales']/(jp_top_5_platforms_and_other['jp_sales'].sum())
jp_top_5_platforms_and_other #посчитаем долю продаж игр каждой платформы
# Out:
#    jp_sales platform  proportion
# 0     23.55      3DS    0.441011
# 1      4.97      PS3    0.093071
# 2     12.05      PS4    0.225655
# 3      8.41      PSV    0.157491
# 4      4.12     WiiU    0.077154
# 5      0.30    other    0.005618

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(jp_top_5_platforms_and_other['proportion'],labels = jp_top_5_platforms_and_other['platform'], autopct = '%1.1f%%',shadow= True, \
radius = 1, normalize=True);
plt.title('Доля продаж компьютерных игр по платформам  в Японии')
plt.show()

# %% [markdown]
# В Японии вкусы геймеров существенно отличаются от остального рынка компьютерных игр. И в этом регионе PS4 уступает майку лидера 3DS, причём с большим отрывом. И этом при том, что в Европе и Северной Америке игры на платформе 3DS не входили в топ-5 самых продаваемых платформ.В 2015-2016 году в Японии продано свыше 20 млн.копий игр на платформе 3DS, а PS4 только 10 млн копий.
# В Японии доля продаж 3DS составляет 44% от общего объёма продаж, у PS4 - только 23%.
# Игры на платформе XOne, занимавшие в Европе и Северной Америке второе место по общему объёму продаж, в Японии не попали даже в топ-5.
# Третье место по общему объёму продаж в Японии занимают игры на платформе PSV - их доля продаж 16%, а в других регионах эта платформа вовсе не входит в список топовых платформ.

# %% [markdown]
# **4.2.** Определим для пользователя каждого региона (NA, EU, JP) самые популярные жанры (Топ-5). Поясним разницу.

# %% [markdown]
# **4.2.1.** Северная Америка.

# %%
na_genre = games_sorted.pivot_table(index = 'genre', values = 'na_sales', aggfunc = 'sum')
na_genre.sort_values(by='na_sales',ascending=False)
# Out:
#               na_sales
# genre
# shooter          48.18
# action           33.68
# sports           26.31
# role-playing     19.82
# misc              5.58
# fighting          5.54
# adventure         3.84
# platform          3.78
# racing            2.82
# simulation        1.36
# strategy          0.82
# puzzle            0.06

# %%
na_top_5_genre_list = ['shooter','action','sports', 'role-playing', 'misc'] # топ-5 жанров

# %%
na_sales_other_genre_list = na_genre.query('genre not in @na_top_5_genre_list')['na_sales'].sum()
na_sales_other_genre_list #cуммарные продажи по играм, не входящим в топ-5 жанров
# Out:
# 18.21999999999999

# %%
na_genre['genre'] = na_genre.index
na_genre #сделаем жанр столбцом
# Out:
#               na_sales         genre
# genre
# action           33.68        action
# adventure         3.84     adventure
# fighting          5.54      fighting
# misc              5.58          misc
# platform          3.78      platform
# puzzle            0.06        puzzle
# racing            2.82        racing
# role-playing     19.82  role-playing
# shooter          48.18       shooter
# simulation        1.36    simulation
# sports           26.31        sports
# strategy          0.82      strategy

# %%
na_genre.reset_index(drop=True, inplace=True)
na_top_5_genre = na_genre.query('genre in @na_top_5_genre_list').reset_index(drop=True)
na_top_5_genre #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 жанров
# Out:
#    na_sales         genre
# 0     33.68        action
# 1      5.58          misc
# 2     19.82  role-playing
# 3     48.18       shooter
# 4     26.31        sports

# %%
oher_genres_sales = {'na_sales':18.21999999999999,'genre':'other'}
na_top_5_genre_and_other = na_top_5_genre.append(oher_genres_sales, ignore_index=True)
na_top_5_genre_and_other #создадим датафрейм, где помимо топ-5 жанров, будут суммарно отражены продажи по остальным жанрам.
# Out:
#    na_sales         genre
# 0     33.68        action
# 1      5.58          misc
# 2     19.82  role-playing
# 3     48.18       shooter
# 4     26.31        sports
# 5     18.22         other

# %%
na_top_5_genre_and_other.plot.bar(grid=True, figsize=(15, 6), x ='genre')
plt.title('Продажи игр по жанрам в Северной Америке')
plt.show()

# %%
na_top_5_genre_and_other['proportion'] = na_top_5_genre_and_other['na_sales'] / (na_top_5_genre_and_other['na_sales'].sum())
na_top_5_genre_and_other #посчитаем долю продаж игр каждого жанра
# Out:
#    na_sales         genre  proportion
# 0     33.68        action    0.221885
# 1      5.58          misc    0.036761
# 2     19.82  role-playing    0.130575
# 3     48.18       shooter    0.317412
# 4     26.31        sports    0.173332
# 5     18.22         other    0.120034

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(na_top_5_genre_and_other['proportion'],labels = na_top_5_genre_and_other['genre'], autopct = '%1.1f%%',shadow= True, \
radius = 1);
plt.title('Доля продаж компьютерных игр по жанрам  в Северной Америке')
plt.show()

# %% [markdown]
# В Северной Америке самым популярным жанром компьютерных игр являются стрелялки. В исследуемом периоде продано свыше 40 миллионов копий игр в этом жанре и их доля продаж на рынке составляет 32%. Затем идут экшн - 22%, спортивные и ролевы игры - 17% и 13%.

# %% [markdown]
# **4.2.2.** Европа.

# %%
eu_genre = games_sorted.pivot_table(index = 'genre', values = 'eu_sales', aggfunc = 'sum')
eu_genre.sort_values(by='eu_sales',ascending=False)
# Out:
#               eu_sales
# genre
# shooter          40.28
# action           34.82
# sports           27.82
# role-playing     17.21
# racing            6.52
# adventure         4.67
# misc              4.26
# simulation        3.74
# fighting          3.72
# platform          3.20
# strategy          1.57
# puzzle            0.13

# %%
eu_top_5_genre_list = ['shooter','action','sports', 'role-playing', 'racing'] # топ-5 жанров

# %%
eu_sales_other_genre_list = eu_genre.query('genre not in @eu_top_5_genre_list')['eu_sales'].sum()
eu_sales_other_genre_list #cуммарные продажи по играм, не входящим в топ-5 жанров
# Out:
# 21.289999999999992

# %%
eu_genre['genre'] = eu_genre.index
eu_genre #сделаем жанр столбцом
# Out:
#               eu_sales         genre
# genre
# action           34.82        action
# adventure         4.67     adventure
# fighting          3.72      fighting
# misc              4.26          misc
# platform          3.20      platform
# puzzle            0.13        puzzle
# racing            6.52        racing
# role-playing     17.21  role-playing
# shooter          40.28       shooter
# simulation        3.74    simulation
# sports           27.82        sports
# strategy          1.57      strategy

# %%
eu_genre.reset_index(drop=True, inplace=True)
eu_top_5_genre = eu_genre.query('genre in @eu_top_5_genre_list').reset_index(drop=True)
eu_top_5_genre #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 жанров
# Out:
#    eu_sales         genre
# 0     34.82        action
# 1      6.52        racing
# 2     17.21  role-playing
# 3     40.28       shooter
# 4     27.82        sports

# %%
oher_genres_sales_eu = {'eu_sales': 21.289999999999992,'genre':'other'}
eu_top_5_genre_and_other = eu_top_5_genre.append(oher_genres_sales_eu, ignore_index=True)
eu_top_5_genre_and_other #создадим датафрейм, где помимо топ-5 жанров, будут суммарно отражены продажи по остальным жанрам.
# Out:
#    eu_sales         genre
# 0     34.82        action
# 1      6.52        racing
# 2     17.21  role-playing
# 3     40.28       shooter
# 4     27.82        sports
# 5     21.29         other

# %%
eu_top_5_genre_and_other.plot.bar(grid=True, figsize=(15, 6), x ='genre')
plt.title('Продажи игр по жанрам в Европе')
plt.show()

# %%
eu_top_5_genre_and_other['proportion'] = eu_top_5_genre_and_other['eu_sales'] / (eu_top_5_genre_and_other['eu_sales'].sum())
eu_top_5_genre_and_other #посчитаем долю продаж игр каждого жанра
# Out:
#    eu_sales         genre  proportion
# 0     34.82        action    0.235366
# 1      6.52        racing    0.044072
# 2     17.21  role-playing    0.116331
# 3     40.28       shooter    0.272273
# 4     27.82        sports    0.188049
# 5     21.29         other    0.143910

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(eu_top_5_genre_and_other['proportion'],labels = eu_top_5_genre_and_other['genre'], autopct = '%1.1f%%',shadow= True,);
plt.title('Доля продаж компьютерных игр по жанрам  в Европе')
plt.show()

# %% [markdown]
# В Европе самым популярным жанром компьютерных игр также являются стрелялки. В исследуемом периоде продано свыше 35 миллионов копий игр в этом жанре и их доля продаж на рынке составляет 27% . Затем, c небольшим отрывом идёт экшн - 24% , спортивные  игры - 19%, "прочие" игры - 14%, ролевые 12%.Последнее место в топе жанров занимают гонки,их доля продаж в Европе - 4%.

# %% [markdown]
# **4.2.3.** Япония.

# %%
jp_genre = games_sorted.pivot_table(index = 'genre', values = 'jp_sales', aggfunc = 'sum')
jp_genre.sort_values(by='jp_sales',ascending=False)
# Out:
#               jp_sales
# genre
# action           23.05
# role-playing     13.41
# shooter           3.79
# misc              3.19
# adventure         2.22
# simulation        1.93
# sports            1.65
# fighting          1.54
# platform          1.42
# puzzle            0.52
# strategy          0.39
# racing            0.29

# %%
jp_top_5_genre_list = ['action','role-playing','shooter','misc',  'adventure'] # топ-5 жанров

# %%
jp_sales_other_genre_list = jp_genre.query('genre not in @jp_top_5_genre_list')['jp_sales'].sum()
jp_sales_other_genre_list #cуммарные продажи по играм, не входящим в топ-5 жанров
# Out:
# 7.740000000000001

# %%
jp_genre['genre'] = jp_genre.index
jp_genre #сделаем жанр столбцом
# Out:
#               jp_sales         genre
# genre
# action           23.05        action
# adventure         2.22     adventure
# fighting          1.54      fighting
# misc              3.19          misc
# platform          1.42      platform
# puzzle            0.52        puzzle
# racing            0.29        racing
# role-playing     13.41  role-playing
# shooter           3.79       shooter
# simulation        1.93    simulation
# sports            1.65        sports
# strategy          0.39      strategy

# %%
jp_genre.reset_index(drop=True, inplace=True)
jp_top_5_genre = jp_genre.query('genre in @jp_top_5_genre_list').reset_index(drop=True)
jp_top_5_genre #поменяем индекс на нумерацию и оставим в датафрейме только топ-5 жанров
# Out:
#    jp_sales         genre
# 0     23.05        action
# 1      2.22     adventure
# 2      3.19          misc
# 3     13.41  role-playing
# 4      3.79       shooter

# %%
oher_genres_sales_jp = {'jp_sales': 7.740000000000001,'genre':'other'}
jp_top_5_genre_and_other = jp_top_5_genre.append(oher_genres_sales_jp, ignore_index=True)
jp_top_5_genre_and_other #создадим датафрейм, где помимо топ-5 жанров, будут суммарно отражены продажи по остальным жанрам.
# Out:
#    jp_sales         genre
# 0     23.05        action
# 1      2.22     adventure
# 2      3.19          misc
# 3     13.41  role-playing
# 4      3.79       shooter
# 5      7.74         other

# %%
jp_top_5_genre_and_other.plot.bar(grid=True, figsize=(15, 6), x ='genre')
plt.title('Продажи игр по жанрам в Японии')
plt.show()

# %%
jp_top_5_genre_and_other['proportion'] = jp_top_5_genre_and_other['jp_sales'] / (jp_top_5_genre_and_other['jp_sales'].sum())
jp_top_5_genre_and_other #посчитаем долю продаж игр каждого жанра
# Out:
#    jp_sales         genre  proportion
# 0     23.05        action    0.431648
# 1      2.22     adventure    0.041573
# 2      3.19          misc    0.059738
# 3     13.41  role-playing    0.251124
# 4      3.79       shooter    0.070974
# 5      7.74         other    0.144944

# %%
fig1,ax1 = plt.subplots(figsize=(8,8))
ax1.pie(jp_top_5_genre_and_other['proportion'],labels = jp_top_5_genre_and_other['genre'], autopct = '%1.1f%%',shadow= True,);
plt.title('Доля продаж компьютерных игр по жанрам  в Японии')
plt.show()

# %% [markdown]
# Популярные жанры компьютерных игр Японии существенно отличаются от остальных рынков.
# Самый продаваемый жанр компьютерных игр в Японии - экшн, его доля продаж составляет 43%.
# Затем идут ролевы игры - 25%. Доля продаж у "прочих" жанров - 14%. Стрелялки, лидирующие по продажам в Северной Европе и Америке, занимают в Японии лишь 4-ое место по охвату рынка и их доля продаж всго 7%.
# Доля продаж в Японии игр в жанре аркада и приключения составляет 6% и 4 %.

# %% [markdown]
# **4.3.** Определим влияет ли рейтинг ESRB на продажи в отдельном регионе.

# %% [markdown]
# **4.3.1.** Северная Америка.

# %% [markdown]
# Нампомню возрастную классификацию по рейтингу ESRB:
# - E10+ - (от англ. "everyone and older") для всех от 10 лет и старше,
# - T - (от англ. "teenager")  для подростков и старше (12+),
# - M - (от англ. "mature") для взрослых (17+)
# - E  - (от англ. "everyone") для всех,

# %%
na_rating_esrb = games_sorted.query('rating != "возрастная категория не определена"').pivot_table(index = 'rating', \
values = 'na_sales', aggfunc = 'sum')
na_rating_esrb.sort_values(by='na_sales',ascending=False)
# Out:
#         na_sales
# rating
# M          47.03
# E          26.59
# T          22.86
# E10+       17.87

# %%
na_rating_esrb.plot.bar(grid=True, figsize=(15, 6))
plt.title('Продажи игр по рейтингу ESRB в Северной Америке')
plt.show()

# %%
na_rating_esrb['proportion'] = na_rating_esrb['na_sales'] / (na_rating_esrb['na_sales'].sum())
na_rating_esrb
# Out:
#         na_sales  proportion
# rating
# E          26.59    0.232532
# E10+       17.87    0.156275
# M          47.03    0.411281
# T          22.86    0.199913

# %%
na_rating_esrb.plot.pie(y='proportion',figsize=(7, 7),autopct='%1.1f%%', startangle=90, normalize=True)
plt.title('Доля продаж игр по рейтингу ESRB в Северной Америке')
plt.show()

# %% [markdown]
# В Северной Америке игры с рейтингом ESRB "M" - для взрослых являются самыми продаваемыми. За 2015-2016 годы продано свыше 40 миллионов копий игр для данной возрастной категории.
# В Северной Америке доля продаж игр для взрослых составляет 41% от общего объёма. Затем идут игры для всех возрастов, категория "E" и для тинейджеров - "T"- , их доли продаж составляют 23% и 20%. Наименее популярны игры с возрастной категорией "E10+" - их доля продаж только 15%.

# %% [markdown]
# **4.3.2.** Европа.

# %%
eu_rating_esrb = games_sorted.query('rating != "возрастная категория не определена"').pivot_table(index = 'rating', \
values = 'eu_sales', aggfunc = 'sum')
eu_rating_esrb.sort_values(by='eu_sales',ascending=False)
# Out:
#         eu_sales
# rating
# M          45.54
# E          34.83
# T          20.32
# E10+       11.54

# %%
eu_rating_esrb.plot.bar(grid=True, figsize=(15, 6))
plt.title('Продажи игр по рейтингу ESRB в Европе')
plt.show()

# %%
eu_rating_esrb['proportion'] = eu_rating_esrb['eu_sales'] / (eu_rating_esrb['eu_sales'].sum())
eu_rating_esrb
# Out:
#         eu_sales  proportion
# rating
# E          34.83    0.310345
# E10+       11.54    0.102825
# M          45.54    0.405774
# T          20.32    0.181057

# %%
eu_rating_esrb.plot.pie(y='proportion',figsize=(7, 7),autopct='%1.1f%%', startangle=90,normalize=True)
plt.title('Доля продаж игр по рейтингу ESRB в Европе')
plt.show()

# %% [markdown]
# Как и в Северной Америке, самыми продаваемыми играми в Европе являются игры с рейтингом ESRB "M" - для взрослых. За 2015-2016 годы в Европе продано свыше 40 миллионов копий игр для данной возрастной категории.
# В Европе доля продаж игр для взрослых составляет 41% от общего объёма.
# Затем идут игры для всех возрастов, категория "E" и для тинейджеров - "T"- , их доли продаж составляют 31% и 18%. Наименее популярны игры с возрастной категорией "E10+" - их доля продаж только 10%.

# %% [markdown]
# **4.3.3.** Япония.

# %%
jp_rating_esrb = games_sorted.query('rating != "возрастная категория не определена"').pivot_table(index = 'rating', \
values = 'jp_sales', aggfunc = 'sum')
jp_rating_esrb.sort_values(by='jp_sales',ascending=False)
# Out:
#         jp_sales
# rating
# T           7.70
# E           5.25
# M           4.29
# E10+        3.27

# %%
jp_rating_esrb.plot.bar(grid=True, figsize=(15, 6))
plt.title('Продажи игр по рейтингу ESRB в Японии')
plt.show()

# %%
jp_rating_esrb['proportion'] = jp_rating_esrb['jp_sales'] / (jp_rating_esrb['jp_sales'].sum())
jp_rating_esrb
# Out:
#         jp_sales  proportion
# rating
# E           5.25    0.255973
# E10+        3.27    0.159434
# M           4.29    0.209166
# T           7.70    0.375427

# %%
jp_rating_esrb.plot.pie(y='proportion',figsize=(7, 7),autopct='%1.1f%%', startangle=90,normalize=True)
plt.title('Доля продаж игр по рейтингу ESRB в Японии')
plt.show()

# %% [markdown]
# Япония как всегда стоит особняком в мире компьютерных игр. В отличае от Севереной Америки и Европы, где наибольшей популярностью пользуются игры для взрослых, здесь самые продаваемые игры по рейтингу ESRB - для тинейджеров (категория "T"). Их доля на рынке составляет 38%, затем идут игры для всех возрастных категорий (26%) и только потом - игры для взрослых (21%). Игры с возрастным ограничением 10+ и в Японии занимают последнее место - их доля на рынке продаж 16%.

# %% [markdown]
# <a id = 'r11'></a>
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>  На доработку</b>🤔:
#
# После добавления заглушки [тут](#r1) нужно пересмотреть это распределения и сделать вывод о рейтинговой системе Японии.
#
# Остальное верно.

# %% [markdown]
# <div class="alert-info">
# Андрей, в столбце рейтинг уже поставлена "заглушка"  - см. ввод [31]. Блок 4.3. сделан с сортировкой рейтинга по этой заглушке: query('rating != "возрастная категория не определена"'.
#
# </div>

# %% [markdown]
# <a id = 'g1'></a>
# <div class="alert alert-success">
#
# Тогда прошу прощения, увидел график без этой категории просто. На будущее - лучше отражать пропуски которые имеют какое-то логическое основание, как здесь - в Японии другая система рейтингов.

# %% [markdown]
# <a id = 'g1'></a>
# <div class="alert alert-success">
#
# **Факультатив**
#
# Отлично что используешь seaborn, вот еще одна библиотека, позволяющая делать красивые графики
#
#     https://plotly.com/python/
#
# Она гораздно обширнее и в ней больше возможностей настройки а так же много дополнительных библиотек строится повер  plotly, например dash - https://dash.plotly.com/ - позволит делать интерактивные графики (ползунки, кнопки прямо в графике) и выводить их на отдельный адрес(там с сервером придется повозится), адрес которого можно скидывать кому угодно. Сейчас это врядли тебе понадобится, но на будущее, если изучишь - то большой плюс на работе будет.
#
# Вот также статья хорошая на русском:
#
#     https://habr.com/ru/company/skillfactory/blog/506974/
#
# PS если хочешь быстро строить графики как в seaborn, то есть библиотека cufflinks, в статье о ней написано тоже.
#
# В ней очень просто строятся графики, они очень хорошо оформлены и их более чем достаточно для задач анализа данных.

# %% [markdown]
# **5. Проверим гипотезы**.

# %% [markdown]
# **5.1.** Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# Hулевая гипотеза всегда формулируется так, чтобы использовать знак равенства. Другими словами, чтобы все данные лежали в районе изначально предполагаемого значения. Руководствуясь этим правилом сформулирую нулевую гипотезу. Затем сформулирую альтернативную гипотезу, которая противоречит нулевой гипотезе.
#
# Нулевая гипотеза: средний пользовательсткий рейтинг платформы Xbox One = среднему пользовательскому рейтингу платформы PC.
# Альтернативная гипотеза: средний пользовательсткий рейтинг платформы Xbox One != среднему пользовательскому рейтингу платформы PC.

# %%
alpha = 0.05 # критический уровень статистической значимости.если p-value окажется меньше него - отвергнем гипотезу.
xbox_one = games.query('platform == "XB" and user_score != 77.7')
pc = games.query('platform == "PC" and user_score != 77.7')
results =  st.ttest_ind(xbox_one['user_score'], pc['user_score'],equal_var = False)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 3.69017314357026e-08
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вероятность того, что средний пользовательсткий рейтинг платформы Xbox One равен  среднему пользовательскому рейтингу платформы PC  очень мала, и эта вероятность меньше критического уровня сатистической значимости. Таким образом у меня есть основание отвергнуть нулевую гипотезу, ведь экспериментальные данные очень маловероятны при условии, что гипотеза верна.

# %% [markdown]
# **5.2.** Средние пользовательские рейтинги жанров Action  и Sports разные.

# %% [markdown]
# Hулевая гипотеза всегда формулируется так, чтобы использовать знак равенства. Другими словами, чтобы все данные лежали в районе изначально предполагаемого значения. Руководствуясь этим правилом сформулирую нулевую гипотезу. Затем сформулирую альтернативную гипотезу, которая противоречит нулевой гипотезе.
#
# Нулевая гипотеза: средний пользовательсткий рейтинг жанра экшн = среднему пользовательскому рейтингу жанра спорт.
# Альтернативная гипотеза: средний пользовательсткий рейтинг жанра экшн != среднему пользовательскому рейтингу жанра спорт.

# %%
alpha = 0.05 # критический уровень статистической значимости.если p-value окажется меньше него - отвергнем гипотезу.
action = games.query('genre == "action"')
sports = games.query('genre == "sports"')
results =  st.ttest_ind(action['user_score'], sports['user_score'],equal_var = False)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 5.831842259068819e-08
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вероятность того, что средний пользовательсткий рейтинг жанра экшн равен среднему пользовательскому рейтингу жанра спорт  очень мала, и эта вероятность меньше критического уровня сатистической значимости. Таким образом у меня есть основание отвергнуть нулевую гипотезу, ведь экспериментальные данные очень маловероятны при условии, что гипотеза верна.
#                                                                                                                               Что касается альтернативной гипотезы о том, что у игр жанра экшн и спорт средние пользовательские рейтинги разные: данные гипотезе не противоречат, мы её не отвергаем.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
# <b> 5 Все отлично!</b> 🏆:
#
# Все верно.
#
# </div>

# %% [markdown]
# **6.Общий вывод**

# %% [markdown]
# Проведено исследование находящихся в открытом доступе исторических данных за период с 1980 по 2016 годы о продажах компьютерных игр, оценке пользователей и экспертов, жанрах и платформах  с целью выявления  особенностей и закономерностей, определяющих успешность игры, а также, чтобы спланировать рекламные кампании на 2017 год в интернет-магазине «Стримчик» и сделать ставку на потенциально популярный продукт.
#
# Для подготовки к исследованию была проведена предобработка данных:
# - Изменён тип данных в столбцах
# - Заполнены пропущенные значения там, где это возможно
# - Устанены неявные дубликаты
# - В случаях, где пропущенные значения востановить невозможно, пропуски были заменены на "заглушки".
# - Для дальнейшего исследования в датафрейм был добавлен столбц total_sales c общими продажами компьютерных игр по всем регионам.
#
# В ходе исследовательского анализа данных было установлено:
# -  С момента появления компьютерных игр в 80-ые годы прошлого века количество ежегодно выпускаемых игр неуклонно росло вплоть до 2008-2009 года, где достигло пиковой отметки 1400 игр в год. Затем, вплоть до 2013 года включительно фиксируется значительный спад. В 2015-2016 году количество ежегодно выпускаемых игр составляет 500-600 игр в год.
# - Жизненный цикл игровых платформ в среднем длится около 10 лет. Развитие каждой платформы идёт по нарастающей до определённого пика, затем идёт спад после которго она прекращает своё существование.
# - Актуальным периодом для исследования является 2015 и 2016 годы. Данные до 2015 года не актуальны, т.к. до этого года наблюдался рост продаж по представленным на рынке платформам, а с 2015 года мы работаем в условиях снижения количества продаж.Также важно, чтобы в анализе участвовали только актуальные на данный момент платформы.
# - Бесспорным лидером по общему объёму продаж в ислледуемом периоде является платформа "PS4" - продано 188 млн.копий.Также в топ-5 по общему объёму продаж вошли "XOne" - 86 млн.копий,"3DS" - 42 млн.копий,"PS3" и "WiiU" - по 20 млн.копий каждая. У всех этих платформ в исследуемом периоде наблюдается снижение продаж.И в 2017 году ожидается продолжение спада, что является типичной моделью жизненного цикла платформы, прошедшей пиковые значения продаж.
# - По медианному значению общих продаж и по значению 3-его квартиля самые высокие показатели - у платформ XOne и PS4, однако общее количество продаж(count), бесспорно больше у PS4. Поэтому, в исследуемом периоде  платформа является бесспорным лидером на рынке компьютерных игр.
# - И для самой продаваемой платформы PS4 и для других платформ связь между оценками критиков и продажами выше(коэффициенты корреляции для PS4 = 0,4, для остальных = 0,3), чем связь между оценками пользователей и продажами (коэффициенты корреляции для PS4 = -0,06, для остальных = 0,03).
# - Самым продаваемым жанром игр являются стрелялки и экшн, в исследуемом периоде продано свыше 100 млн.копий игр кадого из этих жанров. Затем идут спортивные и ролевые игры - 60 и 50 млн.копий соответственно. Обделены вниманием пользователей пазлы и стратегии.

# %% [markdown]
# В ходе анализа был составлен портрет пользователя каждого региона.
# 1. Для пользователя каждого региона (NA, EU, JP) определены самые популярные платформы:
# - В Северной Америке абсолютным лидером продаж является платформа PS4, в 2015-2016 году продано свыше 60 млн.копий игр на данной платформе. На долю PS4 приходится 42% всех продаж в данном регионе. Затем идёт XOne с 33%. Доля продаж у всех остальных платформ - в диапазоне 5-7% у каждой (7% - это категория в которой несколько платформ с низкими показателями продаж).
# - В Европе лидерские позиции PS4 укрепляются ещё сильнее, в 2015-2016 году продано свыше 80 млн.копий игр на данной платформе.
# В Европе доля PS4 составляет уже  57% от всех продаж.
# А вот охват рынка у  XOne, по сравнению с Северной Америкой, меньше - только 19%.
# Доля продаж игр на остальных платформах находится в диапазоне 5-8% каждая (8% - это категория в которой несколько платформ с низкими показателями продаж).
# - В Японии вкусы геймеров существенно отличаются от остального рынка компьютерных игр. И в этом регионе PS4 уступает майку лидера 3DS, причём с большим отрывом. И этом при том, что в Европе и Северной Америке игры на платформе 3DS не входили в топ-5 самых продаваемых платформ.В 2015-2016 году в Японии продано свыше 20 млн.копий игр на платформе 3DS, а PS4 только 10 млн копий.
# В Японии доля продаж 3DS составляет 44% от общего объёма продаж, у PS4 - только 23%.
# Игры на платформе XOne, занимавшие в Европе и Северной Америке второе место по общему объёму продаж, в Японии не попали даже в топ-5.
# Третье место по общему объёму продаж в Японии занимают игры на платформе PSV - их доля продаж 16%, а в других регионах эта платформа вовсе не входит в список топовых платформ.
#
# 2. Для пользователя каждого региона (NA, EU, JP) определены самые популярные жанры:
# - В Северной Америке самым популярным жанром компьютерных игр являются стрелялки. В исследуемом периоде продано свыше 40 миллионов копий игр в этом жанре и их доля продаж на рынке составляет 32%. Затем идут экшн - 22%, спортивные и ролевы игры - 17% и 13%.
# - В Европе самым популярным жанром компьютерных игр также являются стрелялки. В исследуемом периоде продано свыше 35 миллионов копий игр в этом жанре и их доля продаж на рынке составляет 27% . Затем, c небольшим отрывом идёт экшн - 24% , спортивные  игры - 19%, "прочие" игры - 14%, ролевые 12%.Последнее место в топе жанров занимают гонки,их доля продаж в Европе - 4%.
# - Популярные жанры компьютерных игр Японии существенно отличаются от остальных рынков.
# Самый продаваемый жанр компьютерных игр в Японии - экшн, его доля продаж составляет 43%.
# Затем идут ролевы игры - 25%. Доля продаж у "прочих" жанров - 14%. Стрелялки, лидирующие по продажам в Северной Европе и Америке, занимают в Японии лишь 4-ое место по охвату рынка и их доля продаж всго 7%.
# Доля продаж в Японии игр в жанре аркада и приключения составляет 6% и 4 %.
#
# 3. Установлено влияет ли рейтинг ESRB на продажи в отдельном регионе.
# - В Северной Америке самыми продаваемыми являются игры с рейтингом ESRB "M" - для взрослых. За 2015-2016 годы продано свыше 40 миллионов копий игр для данной возрастной категории. Доля продаж игр для взрослых составляет здесь 41% от общего объёма. Затем идут игры для всех возрастов, категория "E" и для тинейджеров - "T"- , их доли продаж составляют 23% и 20%. Наименее популярны игры с возрастной категорией "E10+" - их доля продаж только 15%.
# - Самыми продаваемыми играми в Европе также являются игры с рейтингом ESRB "M" - для взрослых. За 2015-2016 годы в Европе продано свыше 40 миллионов копий игр для данной возрастной категории.В Европе доля продаж игр для взрослых составляет 41% от общего объёма.Затем идут игры для всех возрастов, категория "E" и для тинейджеров - "T"- , их доли продаж составляют 31% и 18%. Наименее популярны игры с возрастной категорией "E10+" - их доля продаж только 10%.
# - Япония как всегда стоит особняком в мире компьютерных игр. В отличае от Севереной Америки и Европы, где наибольшей популярностью пользуются игры для взрослых, здесь самые продаваемые игры по рейтингу ESRB - для тинейджеров (категория "T"). Их доля на рынке составляет 38%, затем идут игры для всех возрастных категорий (26%) и только потом - игры для взрослых (21%). Игры с возрастным ограничением 10+ и в Японии занимают последнее место - их доля на рынке продаж 16%.

# %% [markdown]
# В ходе исследования были проверены следующие гипотезы:
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#  Вероятность того, что средний пользовательсткий рейтинг платформы Xbox One равен  среднему пользовательскому рейтингу платформы PC  очень мала, и эта вероятность меньше критического уровня сатистической значимости. Таким образом у меня есть основание отвергнуть нулевую гипотезу, ведь экспериментальные данные очень маловероятны при условии, что гипотеза верна.
#
# 2. Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.Что касается альтернативной гипотезы о том, что у игр жанра экшн и спорт средние пользовательские рейтинги разные: данные гипотезе не противоречат, мы её не отвергаем.

# %% [markdown]
# На основании проведённого анализа рынка компьютерных игр с целью  определения потенциально популярного продукта, выявления  особенностей и закономерностей, определяющих успешность игры, а также, для планирования  рекламной кампании на 2017 год, **сформулирован ряд рекомендаций для интернет-магазина «Стримчик»:**
# - Если целевой аудиторией магазина являются европейские или северо-американские пользователи, то потенциально- прибыльной будет продажа игр на базе платформ PS4 и XOne, т.к. на этих рынках они занимают лидирующие позиции.Но поскольку их жизненный цикл идёт на спад, то объём продаж в 2017 году будет меньше, чем в 2016. Самыми прибыльными игровыми жанрами для продаж в Европу и Северную Америку будут стреляки и экшн; что касается возрастной категории по версии ESRB - то целесообрразно продавать игры для взрослых и для всех возрастов.
# - Если  "Стримчик" планирует развивать интрнет-продажи для японских пользователей, то здесь нужно сделать ставку на игры, основанные на платформе 3DS а затем,с существенным отрывом, PS4. Жизненный цикл обемх платформ идёт на спад, поэтому ожидаемый  объём продаж в 2017 году будет меньше, чем в 2016. Потенциально прибыльным жанром компьютерных игр играм для данного рынка будет экшн, затем ролевые игры. В плане продаваемости игр по рейтингу ESRB японцы также стоят особником: наиболее выгодно для данной целевой аудитории будет продавать игры для тинейджеров и для всех возрастов.
# - Взаимосвязь между оценками критиков и продажами игр выше, чем взаимосвязь между оценками пользователей и продажами, поэтому считаю целесообразным рассмотреть привлечение критиков и блогеров для рекламного обзора своего игрового ассортимента.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b> 6 Некоторые замечания и рекомендации</b>🔎:
#
# Согласно полученным результатам выводы корректны, развернуты и хорошо сформултрованны. Не забудь пересмотреть после доработок.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <h2>Общий вывод по проекту <a class="tocSkip"></h2>
#
# Cпасибо за твой проект! Было приложено много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом! Есть несколько важных моментов, которые я отметил и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Работа отличная. Ознакомься с рекомендациями, что прокачиваться дальше)
#
#
# **На что стоит обратить внимание🤓**:
#
# * [можно дополнить некоторые пункты предобработки данных](#p2)
# * [нужно исправить некоторые моменты в исследовательском анализе](#p3)
# * [Нужна небольшая правка по рейтингу в Японии](#r11)
# * советы по работе с графиками [тут](#g1)
#
# **На что стоит обратить внимание🤓**:
#
# Все исправлено корректно) Добавлю, что в рейтингах у Японии много пропусков из-за того, что у них своя система рейтингов, а в этой таблице учитывалась только западная система.
#
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**
#
# **PS! Работа и вправду отличная**
#
# ![gif](https://media1.giphy.com/media/111ebonMs90YLu/giphy.gif?cid=ecf05e47squ85946qbqcaht8169a29teug2h55iz61x9l1k8&rid=giphy.gif&ct=g)
